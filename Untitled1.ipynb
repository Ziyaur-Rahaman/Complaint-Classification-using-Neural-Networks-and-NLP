# %%
import pandas as pd
import numpy as np

# %%
unique_df=pd.read_csv("unique_vlaue_dataset.csv")

# %%
unique_df.shape
# Out:
# (90, 2)

# %%
complaints_data = [
    {"Complaint Text": "Double payment processed for one membership on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Double payment processed for one enrollment on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Double payment processed for one course access on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Double payment processed for one enrollment on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Double payment processed for one membership on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Double payment processed for one enrollment on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Double payment processed for one account on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Double payment processed for one plan on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Double payment processed for one membership on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Double payment processed for one membership on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Course progress is resetting properly on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Course progress is disappearing properly on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Course progress is not updating properly on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Course progress is not recorded properly on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Course progress is lost properly on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Course progress is resetting properly on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Course progress is not recorded properly on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Course progress is disappearing properly on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Course progress is disappearing properly on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Course progress is not updating properly on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Payment failed but amount debited from my account on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Payment failed but amount debited from my account on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Payment failed but amount debited from my account on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Payment failed but amount debited from my account on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Payment failed but amount debited from my account on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Payment failed but amount debited from my account on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Payment failed but amount debited from my account on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Payment failed but amount debited from my account on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Payment failed but amount debited from my account on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Payment failed but amount debited from my account on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy instructor gave old material.", "Category": "Instructor Issue"},
    {"Complaint Text": "Codecademy instructor shared obsolete content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Codecademy instructor didn’t update content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Codecademy instructor posted outdated lectures.", "Category": "Instructor Issue"},
    {"Complaint Text": "Codecademy instructor used old syllabus.", "Category": "Instructor Issue"},
    {"Complaint Text": "Codecademy instructor shared obsolete content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Codecademy instructor gave old material.", "Category": "Instructor Issue"},
    {"Complaint Text": "Codecademy instructor posted outdated lectures.", "Category": "Instructor Issue"},
    {"Complaint Text": "Codecademy instructor used old syllabus.", "Category": "Instructor Issue"},
    {"Complaint Text": "Codecademy instructor didn’t update content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Course syllabus missed important modules on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Course syllabus left out core concepts on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Course syllabus ignored necessary lessons on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Course syllabus excluded essential subjects on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Course syllabus missed main content on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Course syllabus left out core concepts on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Course syllabus excluded essential subjects on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Course syllabus missed important modules on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Course syllabus ignored necessary lessons on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Course syllabus missed main content on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Customer care at Codecademy failed to confirm my payment successfully.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Customer care at Codecademy unable to validate my payment successfully.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Customer care at Codecademy didn’t authenticate my payment successfully.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Customer care at Codecademy not able to verify my payment successfully.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Customer care at Codecademy unable to check my payment successfully.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Customer care at Codecademy failed to confirm my payment successfully.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Customer care at Codecademy didn’t authenticate my payment successfully.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Customer care at Codecademy not able to verify my payment successfully.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Customer care at Codecademy unable to check my payment successfully.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Customer care at Codecademy unable to validate my payment successfully.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy app is missing the purchased course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy app is invisible the purchased course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy app is not listed the purchased course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy app is not appearing the purchased course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy app is not available the purchased course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy app is invisible the purchased course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy app is missing the purchased course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy app is not listed the purchased course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy app is not appearing the purchased course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy app is not listed the purchased course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Course instructions on Codecademy are confusing.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Course instructions on Codecademy are unclear.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Course instructions on Codecademy are ambiguous.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Course instructions on Codecademy are not well explained.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Course instructions on Codecademy are vague.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Course instructions on Codecademy are unclear.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Course instructions on Codecademy are ambiguous.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Course instructions on Codecademy are confusing.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Course instructions on Codecademy are not well explained.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Course instructions on Codecademy are not well explained.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Instructor no new updates the Codecademy course content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor halted updates the Codecademy course content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor not uploading new material the Codecademy course content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor inactive the Codecademy course content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor paused updates the Codecademy course content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor no new updates the Codecademy course content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor halted updates the Codecademy course content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor paused updates the Codecademy course content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor not uploading new material the Codecademy course content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor inactive the Codecademy course content.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor didn't respond to multiple questions from learners on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor overlooked multiple questions from learners on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor neglected multiple questions from learners on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor didn't reply to multiple questions from learners on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor dismissed multiple questions from learners on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor overlooked multiple questions from learners on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor neglected multiple questions from learners on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor didn't respond to multiple questions from learners on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor dismissed multiple questions from learners on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "Instructor didn't reply to multiple questions from learners on Codecademy.", "Category": "Instructor Issue"},
]

# %%
complaints_data += [
    # 11. Content outdated and not useful
    {"Complaint Text": "The Codecademy course content is outdated and not useful.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy course content is obsolete and not helpful.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy course content is not current and lacks relevance.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy course content feels old and ineffective.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy course content is not updated and lacks quality.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy course content is outdated and lacks clarity.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy course material is not relevant anymore.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy course content is no longer applicable.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy course contains out-of-date information.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy content is from older versions of tools.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy course content is stale and not useful.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy curriculum is outdated and needs revision.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy lessons are old and poorly maintained.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy course modules are not updated.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy videos contain outdated practices.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy learning material is obsolete.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy training is irrelevant to current standards.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy tutorials are no longer valid.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy resources are outdated and confusing.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy course is behind current industry standards.", "Category": "Content Quality Issue"},

    # 12. Free course required payment midway
    {"Complaint Text": "The free course on Codecademy required payment midway.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy free course became paid halfway through.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy advertised free course but asked for payment later.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy course was not completely free as claimed.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Mid-course, Codecademy asked for a fee in the free course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy switched the course from free to paid.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy required upgrade in the middle of free course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The free course at Codecademy wasn't actually free.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy tricked users into starting a free course, then charged.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy free trial course had hidden fees.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy free course locked content behind a paywall.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy charged midway in a supposedly free course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy falsely labeled a paid course as free.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Free course on Codecademy required subscription mid-way.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy converted free course to premium halfway.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy free course turned paid after a few lessons.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy didn't disclose payment for later course sections.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy removed access to free content mid-course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy offered a free course but demanded payment later.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy falsely advertised free access to full course.", "Category": "Misleading Course Description"},
]

# %%
complaints_data += [
    # 13. Codecademy mobile app crashes frequently
    {"Complaint Text": "The Codecademy app crashes frequently during use.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy app keeps closing unexpectedly.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy mobile app crashes after login.", "Category": "Technical Glitch"},
    {"Complaint Text": "The app crashes every time I start a new lesson on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy app stops working after few minutes.", "Category": "Technical Glitch"},
    {"Complaint Text": "Unable to use Codecademy app due to frequent crashes.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy app hangs and crashes often.", "Category": "Technical Glitch"},
    {"Complaint Text": "The mobile app crashes when accessing course content.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy mobile application isn't stable and crashes frequently.", "Category": "Technical Glitch"},
    {"Complaint Text": "App keeps crashing when I open my course on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "Every time I resume a course, Codecademy app crashes.", "Category": "Technical Glitch"},
    {"Complaint Text": "App quits unexpectedly on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "Frequent app crashes make Codecademy unusable.", "Category": "Technical Glitch"},
    {"Complaint Text": "Crashing issues persist with Codecademy Android app.", "Category": "Technical Glitch"},
    {"Complaint Text": "iOS version of Codecademy crashes a lot.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy app is unstable and keeps crashing.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy app randomly crashes during exercises.", "Category": "Technical Glitch"},
    {"Complaint Text": "Repeated app crashes on Codecademy while coding.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy crashes every time I press 'Submit'.", "Category": "Technical Glitch"},
    {"Complaint Text": "The app closes unexpectedly when I try to take a quiz.", "Category": "Technical Glitch"},

    # 14. Live chat support never responds
    {"Complaint Text": "Codecademy's live chat support never responds.", "Category": "Customer Support Issue"},
    {"Complaint Text": "No one replies on Codecademy live support chat.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live support is always offline on Codecademy.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live chat on Codecademy is non-functional.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Waiting endlessly for a response on Codecademy live chat.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live chat doesn't connect to a support agent.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy chat bot loops without human intervention.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Support chat on Codecademy ignores my queries.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Chat feature is available but no one answers.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live help feature doesn't actually provide support.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy support chat stays inactive for hours.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live chat support is advertised but doesn't work.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy's live chat team never comes online.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I waited 2 hours for a chat response and got nothing.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live chat on Codecademy is completely unresponsive.", "Category": "Customer Support Issue"},
    {"Complaint Text": "No human support via live chat on Codecademy.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live chat only responds with generic messages.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live chat failed to connect to any agent.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy live chat ends abruptly without help.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Support chat appears but nobody assists.", "Category": "Customer Support Issue"},

    # 15. Codecademy certificate not received after course completion
    {"Complaint Text": "Did not receive certificate after completing Codecademy course.", "Category": "Certificate Issue"},
    {"Complaint Text": "Completed the Codecademy course but no certificate issued.", "Category": "Certificate Issue"},
    {"Complaint Text": "My Codecademy certificate is missing post-course.", "Category": "Certificate Issue"},
    {"Complaint Text": "Still waiting for course certificate from Codecademy.", "Category": "Certificate Issue"},
    {"Complaint Text": "Course completion certificate was never delivered.", "Category": "Certificate Issue"},
    {"Complaint Text": "I finished the course but Codecademy didn't give a certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "Completed Codecademy lessons, but no certification received.", "Category": "Certificate Issue"},
    {"Complaint Text": "Certification is not appearing in my dashboard.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy failed to issue my course certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "Expected a certificate from Codecademy, got nothing.", "Category": "Certificate Issue"},
    {"Complaint Text": "Certificate download option missing post-course.", "Category": "Certificate Issue"},
    {"Complaint Text": "Course marked as completed but no certificate provided.", "Category": "Certificate Issue"},
    {"Complaint Text": "Finished all Codecademy modules, still no certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "Certificate email never arrived after course.", "Category": "Certificate Issue"},
    {"Complaint Text": "I completed the course but didn't receive a certificate link.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy certificate not generated after finishing the course.", "Category": "Certificate Issue"},
    {"Complaint Text": "My certificate is not visible in my account.", "Category": "Certificate Issue"},
    {"Complaint Text": "Still no proof of course completion from Codecademy.", "Category": "Certificate Issue"},
    {"Complaint Text": "Completed Codecademy track, no certificate issued.", "Category": "Certificate Issue"},
    {"Complaint Text": "Certificate reward was promised but never delivered.", "Category": "Certificate Issue"},

    # 16. No refund after cancellation
    {"Complaint Text": "Cancelled subscription but didn't get refund from Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "I canceled my plan but Codecademy didn’t return my money.", "Category": "Refund Issue"},
    {"Complaint Text": "No refund even after prompt cancellation.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy charged me after cancellation.", "Category": "Refund Issue"},
    {"Complaint Text": "Refund is still pending after canceling subscription.", "Category": "Refund Issue"},
    {"Complaint Text": "No refund processed despite cancellation confirmation.", "Category": "Refund Issue"},
    {"Complaint Text": "Cancelled my Codecademy plan but still billed.", "Category": "Refund Issue"},
    {"Complaint Text": "Cancellation processed but refund never came.", "Category": "Refund Issue"},
    {"Complaint Text": "I want a refund but no response from Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy didn’t refund after canceling within trial period.", "Category": "Refund Issue"},
    {"Complaint Text": "Subscription was canceled but no refund initiated.", "Category": "Refund Issue"},
    {"Complaint Text": "Still waiting for refund from Codecademy after plan cancellation.", "Category": "Refund Issue"},
    {"Complaint Text": "I cancelled the plan before renewal and got charged.", "Category": "Refund Issue"},
    {"Complaint Text": "Refund has not been credited even after 10 days.", "Category": "Refund Issue"},
    {"Complaint Text": "Cancelled on time, but refund is missing.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy refused to refund after cancellation.", "Category": "Refund Issue"},
    {"Complaint Text": "I canceled my subscription but no money returned.", "Category": "Refund Issue"},
    {"Complaint Text": "Refund not given despite support ticket raised.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy not processing refund after cancellation.", "Category": "Refund Issue"},
    {"Complaint Text": "Plan canceled but full refund not received.", "Category": "Refund Issue"},

    # 17. Code editor lagging
    {"Complaint Text": "Codecademy code editor is lagging heavily.", "Category": "Technical Glitch"},
    {"Complaint Text": "The online editor in Codecademy is too slow.", "Category": "Technical Glitch"},
    {"Complaint Text": "Typing in Codecademy editor is delayed.", "Category": "Technical Glitch"},
    {"Complaint Text": "Editor response is laggy on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "Severe lag while coding in Codecademy lessons.", "Category": "Technical Glitch"},
    {"Complaint Text": "The code editor on Codecademy is unresponsive.", "Category": "Technical Glitch"},
    {"Complaint Text": "Too much delay in editor actions on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "Code takes time to appear after typing on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy platform lags while running code.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy IDE is sluggish and slow.", "Category": "Technical Glitch"},
    {"Complaint Text": "Can't type properly in Codecademy code editor due to lag.", "Category": "Technical Glitch"},
    {"Complaint Text": "Delay in executing code on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "Editor keeps freezing during coding lessons.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy coding interface is very slow.", "Category": "Technical Glitch"},
    {"Complaint Text": "Every keystroke in Codecademy editor is delayed.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy IDE becomes unresponsive often.", "Category": "Technical Glitch"},
    {"Complaint Text": "Code editor takes seconds to react to typing.", "Category": "Technical Glitch"},
    {"Complaint Text": "Editor not responsive when working on assignments.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy platform lags too much during coding.", "Category": "Technical Glitch"},
    {"Complaint Text": "The lag in Codecademy editor disrupts learning.", "Category": "Technical Glitch"},
]

# %%
complaints_data += [
    {"Complaint Text": "Delayed responses from Codecademy support for urgent billing concerns.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Support from Codecademy took too long to respond about payment issues.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Waited days for Codecademy support to address my payment-related query.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy didn’t respond promptly to my urgent payment complaint.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Response time from Codecademy support is unacceptable for payment issues.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Payment dispute with Codecademy was delayed due to support inaction.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy support delayed resolving urgent account charges.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Repeated emails to Codecademy support about payment went unanswered.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy took too long to handle my billing escalation.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Slow customer support from Codecademy during a crucial payment issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "No timely response from Codecademy on a major payment error.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I needed urgent help with payment but Codecademy support delayed.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy's response time to my billing issue was very poor.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Support didn’t respond fast enough when I faced a Codecademy charge error.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy failed to promptly assist me with a double charge issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Urgent support for payment issue delayed by Codecademy team.", "Category": "Customer Support Issue"},
    {"Complaint Text": "My billing complaint was not resolved on time by Codecademy support.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy support didn’t take timely action on my billing ticket.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Unacceptable delay in resolving payment issue from Codecademy support.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Waited too long for Codecademy to address my support request about charges.", "Category": "Customer Support Issue"},

    {"Complaint Text": "Codecademy live chat support failed to answer any of my questions.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live support on Codecademy didn’t help with my billing problem.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live chat on Codecademy was unhelpful for resolving my access issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The Codecademy support chat session ended without any solution.", "Category": "Customer Support Issue"},
    {"Complaint Text": "My problem remained unresolved despite using Codecademy live chat.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live chat failed to assist me on Codecademy refund issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy chat support could not solve my certificate problem.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Unhelpful chat response from Codecademy during technical issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy live chat ended abruptly without resolving the issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "My issue was ignored by Codecademy chat representative.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy chat support agent gave irrelevant responses.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Received no resolution through Codecademy live chat support.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy chat support disconnected without solving my refund query.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live chat could not provide a solution to my login issue on Codecademy.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy chat support gave generic answers and closed my ticket.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Chat support didn't escalate my complaint properly on Codecademy.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy live chat did not understand my technical concern.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The chat support didn’t address my concerns effectively on Codecademy.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Support agent on Codecademy live chat was not trained to help.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Unresolved issue despite long live chat with Codecademy support.", "Category": "Customer Support Issue"},

    
]

# %%
complaints_data += [
    # Complaint 23 – Auto-renewal Issue
    

    # Complaint 24 – Course Material Mismatch
    {"Complaint Text": "Codecademy course content didn’t match the syllabus shown.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Misleading course structure on Codecademy website.", "Category": "Content Quality Issue"},
    {"Complaint Text": "What was advertised was not delivered in the course.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy course skipped topics mentioned in the overview.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Important modules missing from purchased Codecademy course.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Syllabus mismatch found in Codecademy Python course.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy course did not meet expectations from description.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Bought Codecademy course but key topics were absent.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy’s lessons are different than advertised.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Discrepancy between promo material and actual course on Codecademy.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy course lacked depth promised in overview.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Expected hands-on modules were missing in Codecademy course.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy misrepresented course content.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Actual course flow was different from syllabus on Codecademy.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy promised advanced topics that were not covered.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Course modules were outdated and inconsistent on Codecademy.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy course skipped core lessons I paid for.", "Category": "Content Quality Issue"},
    {"Complaint Text": "False marketing by Codecademy about course structure.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Topics mentioned were not included in the Codecademy lessons.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Paid for a full stack course, but Codecademy gave basics only.", "Category": "Content Quality Issue"},

    # Complaint 25 – Certificate Issue
    {"Complaint Text": "I completed the course but didn’t receive any certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "Certificate not generated after Codecademy course completion.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy didn't send my course completion certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "Certificate link not working on Codecademy.", "Category": "Certificate Issue"},
    {"Complaint Text": "Cannot download my certificate from Codecademy profile.", "Category": "Certificate Issue"},
    {"Complaint Text": "My certificate for Python course is missing on Codecademy.", "Category": "Certificate Issue"},
    {"Complaint Text": "Finished course, but certificate not emailed from Codecademy.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy portal not generating certificates.", "Category": "Certificate Issue"},
    {"Complaint Text": "I passed the final quiz but still no certificate on Codecademy.", "Category": "Certificate Issue"},
    {"Complaint Text": "Certificate never appeared after finishing Codecademy module.", "Category": "Certificate Issue"},
    {"Complaint Text": "Even after completion, no certificate is visible.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy failed to issue my course certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "Not able to retrieve certificate after completing Codecademy course.", "Category": "Certificate Issue"},
    {"Complaint Text": "Certificate generation failed despite 100% progress on Codecademy.", "Category": "Certificate Issue"},
    {"Complaint Text": "Still waiting for Codecademy to generate my certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy certificate system is broken.", "Category": "Certificate Issue"},
    {"Complaint Text": "Didn’t get a certificate after completing the course.", "Category": "Certificate Issue"},
    {"Complaint Text": "I was promised a certificate but nothing received yet.", "Category": "Certificate Issue"},
    {"Complaint Text": "No access to my course certificate on Codecademy dashboard.", "Category": "Certificate Issue"},
    {"Complaint Text": "Unable to download or view Codecademy certificate.", "Category": "Certificate Issue"},

    # Complaints 26 to 32 – Will be added in the next message due to space.
]

# %%
complaints_data += [
    {"Complaint Text": "Still waiting on Codecademy support for my urgent payment issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy support delayed responses to my critical billing problem.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Urgent payment concerns on Codecademy not addressed promptly by support.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy's delayed response to a serious payment problem frustrated me.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Support team on Codecademy took too long for urgent payment help.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Slow support response on urgent financial issue with Codecademy.", "Category": "Customer Support Issue"},
    {"Complaint Text": "My emergency payment ticket on Codecademy wasn’t handled swiftly.", "Category": "Customer Support Issue"},
    {"Complaint Text": "No quick support from Codecademy during my billing emergency.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Support team was too slow to help with Codecademy payment issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Waited days for Codecademy support to resolve my urgent payment concern.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy's chat support failed to assist me in a timely manner.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Support team at Codecademy failed to reply during a payment dispute.", "Category": "Customer Support Issue"},
    {"Complaint Text": "No proper help from Codecademy support for my urgent transaction issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Had to wait too long for Codecademy to reply to a payment complaint.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy’s payment issue support lacks urgency.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Facing delays in support on Codecademy for urgent billing matters.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Unacceptable delay by Codecademy in resolving urgent payment ticket.", "Category": "Customer Support Issue"},
    {"Complaint Text": "No quick solution from Codecademy support for my payment problem.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Support failed to acknowledge my critical payment issue on time.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Slow reaction from Codecademy support regarding financial dispute.", "Category": "Customer Support Issue"},

    {"Complaint Text": "Codecademy's live chat agent couldn’t resolve my login problem.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Chat support from Codecademy was unhelpful for my technical query.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live support chat failed to give me the needed help on Codecademy.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Got no resolution from Codecademy’s chat support team.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy’s live chat couldn’t solve my issue despite multiple tries.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live chat agent from Codecademy gave incorrect advice.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy’s chat feature failed to deliver real support.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live help on Codecademy couldn’t answer my basic questions.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live support disconnected before resolving my Codecademy issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy chat couldn’t help me despite multiple attempts.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Chat assistant on Codecademy kept redirecting without solving issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live support from Codecademy provided no real resolution.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy's chat tool failed in my account recovery process.", "Category": "Customer Support Issue"},
    {"Complaint Text": "No help received via Codecademy’s live support portal.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Tried chat on Codecademy but got no satisfactory answers.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live support failed to act on my Codecademy issue report.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy chat representatives were not knowledgeable.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Couldn’t fix my technical glitch via Codecademy’s live chat.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Got stuck with a bug and Codecademy’s chat gave no help.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Live support didn’t solve anything during my Codecademy session.", "Category": "Customer Support Issue"},
    
    # ... continued for complaints 23 to 32
]

# %%
complaints_data += [
    # Complaint 33 – Misleading Course Description
    {"Complaint Text": "The course content on Codecademy was different from what the preview showed.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's course was not as advertised in the preview video.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I was misled by the course description on Codecademy; the content was different.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The actual course material on Codecademy did not align with the syllabus shown.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's course outline was deceptive and didn't match the lessons.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Enrolled in a Codecademy course based on a preview that was inaccurate.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The promotional video for the Codecademy course was completely different from the real content.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's course did not deliver what the preview promised.", "Category": "Misleading Course Description"},
    {"Complaint Text": "What Codecademy showed in the preview wasn't included in the actual course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The topics covered in the Codecademy course were not the ones from the preview.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Felt cheated by Codecademy's misleading course preview.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's course description was a bait-and-switch.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course I paid for on Codecademy didn't match its promotional material.", "Category": "Misleading Course Description"},
    {"Complaint Text": "There was a major discrepancy between the Codecademy course preview and the course itself.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The learning outcomes described by Codecademy didn't match the course content.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy is using false advertising for its course previews.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course structure on Codecademy was not what the preview suggested.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Misled by an inaccurate course syllabus on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's course content seriously diverged from its description.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The preview set false expectations for the Codecademy course I took.", "Category": "Misleading Course Description"},
]

# %%
complaints_data += [
    # Complaint 34 – Payment Issue (Unexpected Charges)
    {"Complaint Text": "Codecademy charged me for something I did not purchase.", "Category": "Payment Issue"},
    {"Complaint Text": "Found an unauthorized charge from Codecademy on my bank statement.", "Category": "Payment Issue"},
    {"Complaint Text": "My account was overcharged by Codecademy without any explanation.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy applied extra fees to my subscription without my knowledge.", "Category": "Payment Issue"},
    {"Complaint Text": "There are mysterious charges from Codecademy on my credit card.", "Category": "Payment Issue"},
    {"Complaint Text": "I was billed by Codecademy for more than the agreed subscription price.", "Category": "Payment Issue"},
    {"Complaint Text": "My Codecademy invoice shows costs that I did not approve.", "Category": "Payment Issue"},
    {"Complaint Text": "Noticed a strange and unexpected charge from Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy took more money from my account than they were supposed to.", "Category": "Payment Issue"},
    {"Complaint Text": "Unexplained billing activity from Codecademy on my account.", "Category": "Payment Issue"},
    {"Complaint Text": "I'm seeing a payment to Codecademy that I don't recognize.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy's billing is not transparent; I found hidden charges.", "Category": "Payment Issue"},
    {"Complaint Text": "A charge appeared from Codecademy that I did not authorize.", "Category": "Payment Issue"},
    {"Complaint Text": "My invoice from Codecademy has an amount I did not agree to pay.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy processed a payment that was completely unexpected.", "Category": "Payment Issue"},
    {"Complaint Text": "I was charged by Codecademy for an unknown reason.", "Category": "Payment Issue"},
    {"Complaint Text": "There is an erroneous charge from Codecademy on my account.", "Category": "Payment Issue"},
    {"Complaint Text": "My Codecademy subscription cost more than what was advertised.", "Category": "Payment Issue"},
    {"Complaint Text": "Discovered a payment discrepancy on my Codecademy account.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy billed me for services I never signed up for.", "Category": "Payment Issue"},
]

# %%
complaints_data += [
    # Complaint 35 – Payment Issue (Incorrect Billing Cycle)
    {"Complaint Text": "I chose a monthly plan, but Codecademy charged me for a full year.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy billed me annually instead of on the monthly basis I selected.", "Category": "Payment Issue"},
    {"Complaint Text": "The billing period on my Codecademy subscription is completely wrong.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy charged my account for the wrong subscription term.", "Category": "Payment Issue"},
    {"Complaint Text": "I was incorrectly put on an annual cycle by Codecademy when I chose monthly.", "Category": "Payment Issue"},
    {"Complaint Text": "My billing frequency with Codecademy is not what I signed up for.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy applied the wrong billing plan to my account.", "Category": "Payment Issue"},
    {"Complaint Text": "Selected monthly payments, but Codecademy charged me for the whole year upfront.", "Category": "Payment Issue"},
    {"Complaint Text": "The charge from Codecademy was for a yearly plan, not the monthly one I wanted.", "Category": "Payment Issue"},
    {"Complaint Text": "My Codecademy invoice shows a yearly charge, but I opted to pay monthly.", "Category": "Payment Issue"},
    {"Complaint Text": "My subscription was supposed to be monthly, but Codecademy billed me for 12 months.", "Category": "Payment Issue"},
    {"Complaint Text": "The billing term applied by Codecademy was not what I selected during checkout.", "Category": "Payment Issue"},
    {"Complaint Text": "I have a dispute with Codecademy over the incorrect length of the billing cycle.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy made an error with my subscription's billing period.", "Category": "Payment Issue"},
    {"Complaint Text": "Charged for an entire year upfront by Codecademy against my selection.", "Category": "Payment Issue"},
    {"Complaint Text": "My account reflects the wrong billing cycle from Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy did not honor the monthly billing option I chose at sign-up.", "Category": "Payment Issue"},
    {"Complaint Text": "There's a major error in my subscription's billing cycle on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "I was billed for a different payment cycle than I agreed to by Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy processed a payment for a yearly plan I did not want or select.", "Category": "Payment Issue"},
]

# %%
complaints_data += [
    # Complaint 36 – Certificate Issue
    {"Complaint Text": "My Codecademy certificate link is broken and shows an error.", "Category": "Certificate Issue"},
    {"Complaint Text": "The public link for my Codecademy certificate is not working.", "Category": "Certificate Issue"},
    {"Complaint Text": "When I share my Codecademy certificate, the verification page fails to load.", "Category": "Certificate Issue"},
    {"Complaint Text": "Unable to verify my Codecademy certificate through its public URL.", "Category": "Certificate Issue"},
    {"Complaint Text": "The link to my Codecademy certificate is invalid.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy's certificate validation page isn't working for my credential.", "Category": "Certificate Issue"},
    {"Complaint Text": "My Codecademy certificate is not publicly accessible via its link.", "Category": "Certificate Issue"},
    {"Complaint Text": "I can't validate my Codecademy certificate using the provided link.", "Category": "Certificate Issue"},
    {"Complaint Text": "The verification for my Codecademy certificate fails every time.", "Category": "Certificate Issue"},
    {"Complaint Text": "There's an issue with the public link for my Codecademy certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "My Codecademy credential cannot be confirmed through the verification link.", "Category": "Certificate Issue"},
    {"Complaint Text": "The shared link for my Codecademy certificate leads to a 404 error.", "Category": "Certificate Issue"},
    {"Complaint Text": "Prospective employers cannot verify my Codecademy certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy's certificate link doesn't prove my completion of the course.", "Category": "Certificate Issue"},
    {"Complaint Text": "The authenticity of my Codecademy certificate can't be checked online.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy provided a faulty link for my certificate verification.", "Category": "Certificate Issue"},
    {"Complaint Text": "My Codecademy certificate appears as invalid when using the public link.", "Category": "Certificate Issue"},
    {"Complaint Text": "The digital verification for my Codecademy certificate is broken.", "Category": "Certificate Issue"},
    {"Complaint Text": "Trying to share my Codecademy certificate, but the link is dead.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy's online certificate checker does not recognize my certificate.", "Category": "Certificate Issue"},
]

# %%
complaints_data += [
    # Complaint 37 – Payment Issue (Coupon Code)
    {"Complaint Text": "My Codecademy coupon didn't apply the discount at checkout.", "Category": "Payment Issue"},
    {"Complaint Text": "I was charged the full price by Codecademy even after applying a discount code.", "Category": "Payment Issue"},
    {"Complaint Text": "The discount from my promo code was not reflected in Codecademy's final charge.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy failed to honor the coupon code I used during payment.", "Category": "Payment Issue"},
    {"Complaint Text": "My Codecademy bill doesn't show the discount from the coupon I entered.", "Category": "Payment Issue"},
    {"Complaint Text": "Applied a valid coupon on Codecademy, but the discount never went through.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy's system accepted my coupon but still charged me the original price.", "Category": "Payment Issue"},
    {"Complaint Text": "The price reduction from my coupon code did not take effect on my Codecademy purchase.", "Category": "Payment Issue"},
    {"Complaint Text": "My Codecademy payment was processed without the promised coupon discount.", "Category": "Payment Issue"},
    {"Complaint Text": "I'm missing the discount on my Codecademy subscription despite using a coupon.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy checkout showed the coupon was applied, but I was overcharged.", "Category": "Payment Issue"},
    {"Complaint Text": "The final amount charged by Codecademy did not include my coupon's discount.", "Category": "Payment Issue"},
    {"Complaint Text": "My promotional code for Codecademy didn't work, and I paid full price.", "Category": "Payment Issue"},
    {"Complaint Text": "There was an error with Codecademy's billing; my coupon discount wasn't applied.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy ignored the coupon I used and billed me the non-discounted rate.", "Category": "Payment Issue"},
    {"Complaint Text": "My attempt to use a discount code on Codecademy was unsuccessful at the payment stage.", "Category": "Payment Issue"},
    {"Complaint Text": "The coupon code was validated on Codecademy, but the discount is missing from my invoice.", "Category": "Payment Issue"},
    {"Complaint Text": "I expected a lower price on Codecademy after using a coupon, but I was charged in full.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy's payment system glitched and didn't apply my discount.", "Category": "Payment Issue"},
    {"Complaint Text": "Paid more than I should have on Codecademy because my coupon was not applied.", "Category": "Payment Issue"},
]

# %%
complaints_data += [
    # Complaint 37 – Payment Issue (Coupon Code)
    {"Complaint Text": "My Codecademy coupon didn't apply the discount at checkout.", "Category": "Payment Issue"},
    {"Complaint Text": "I was charged the full price by Codecademy even after applying a discount code.", "Category": "Payment Issue"},
    {"Complaint Text": "The discount from my promo code was not reflected in Codecademy's final charge.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy failed to honor the coupon code I used during payment.", "Category": "Payment Issue"},
    {"Complaint Text": "My Codecademy bill doesn't show the discount from the coupon I entered.", "Category": "Payment Issue"},
    {"Complaint Text": "Applied a valid coupon on Codecademy, but the discount never went through.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy's system accepted my coupon but still charged me the original price.", "Category": "Payment Issue"},
    {"Complaint Text": "The price reduction from my coupon code did not take effect on my Codecademy purchase.", "Category": "Payment Issue"},
    {"Complaint Text": "My Codecademy payment was processed without the promised coupon discount.", "Category": "Payment Issue"},
    {"Complaint Text": "I'm missing the discount on my Codecademy subscription despite using a coupon.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy checkout showed the coupon was applied, but I was overcharged.", "Category": "Payment Issue"},
    {"Complaint Text": "The final amount charged by Codecademy did not include my coupon's discount.", "Category": "Payment Issue"},
    {"Complaint Text": "My promotional code for Codecademy didn't work, and I paid full price.", "Category": "Payment Issue"},
    {"Complaint Text": "There was an error with Codecademy's billing; my coupon discount wasn't applied.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy ignored the coupon I used and billed me the non-discounted rate.", "Category": "Payment Issue"},
    {"Complaint Text": "My attempt to use a discount code on Codecademy was unsuccessful at the payment stage.", "Category": "Payment Issue"},
    {"Complaint Text": "The coupon code was validated on Codecademy, but the discount is missing from my invoice.", "Category": "Payment Issue"},
    {"Complaint Text": "I expected a lower price on Codecademy after using a coupon, but I was charged in full.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy's payment system glitched and didn't apply my discount.", "Category": "Payment Issue"},
    {"Complaint Text": "Paid more than I should have on Codecademy because my coupon was not applied.", "Category": "Payment Issue"},
]

# %%
complaints_data += [
    # Complaint 38 – Content Quality Issue
    {"Complaint Text": "The project instructions on Codecademy are flawed and don't work.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I couldn't complete a Codecademy project because it was broken.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy's project files have errors and don't function as intended.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The final project in my Codecademy course doesn't behave as the lesson describes.", "Category": "Content Quality Issue"},
    {"Complaint Text": "There are major bugs in the Codecademy course projects.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The sample code for the Codecademy project is faulty.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy's guided projects are impossible to follow because they don't work correctly.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The project steps on Codecademy lead to a non-working outcome.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I'm stuck on a Codecademy project that seems to be bugged.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The project requirements on Codecademy are inconsistent with the provided materials.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy course projects are not functioning properly.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The description of the project outcome on Codecademy is misleading.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The provided solutions for Codecademy projects do not work either.", "Category": "Content Quality Issue"},
    {"Complaint Text": "My Codecademy project environment is broken and prevents progress.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Following the Codecademy project guide exactly results in a broken application.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The learning projects on Codecademy have serious quality issues.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy's interactive projects fail to execute as described.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The project specifications on Codecademy do not match the expected results.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The code in the Codecademy projects is outdated and non-functional.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I'm unable to get the Codecademy course project to run correctly.", "Category": "Content Quality Issue"},
]

# %%
complaints_data += [
    # Complaint 39 – Refund Issue
    {"Complaint Text": "Codecademy only gave me a partial refund and I don't know why.", "Category": "Refund Issue"},
    {"Complaint Text": "I was expecting a full refund from Codecademy but only got a portion back.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund from Codecademy was incomplete and no reason was provided.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy didn't refund the full amount of my subscription.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund I received from Codecademy was less than what I was owed.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy processed an incomplete refund for my cancellation.", "Category": "Refund Issue"},
    {"Complaint Text": "I am missing part of my refund from Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "There was no explanation from Codecademy for why my refund was only partial.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy shorted me on my refund without any justification.", "Category": "Refund Issue"},
    {"Complaint Text": "The amount refunded by Codecademy does not match the amount I paid.", "Category": "Refund Issue"},
    {"Complaint Text": "Still waiting for the rest of my refund from Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy issued a partial refund when a full one was promised.", "Category": "Refund Issue"},
    {"Complaint Text": "I'm confused about why my Codecademy refund wasn't for the full price.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy deducted an unknown amount from my refund.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund from Codecademy is incorrect; it's too low.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy has not provided the full refund I am entitled to.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund status with Codecademy shows complete, but the amount is wrong.", "Category": "Refund Issue"},
    {"Complaint Text": "I need Codecademy to explain why they didn't refund the entire amount.", "Category": "Refund Issue"},
    {"Complaint Text": "Received a smaller refund than expected from Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy didn't return all my money as requested.", "Category": "Refund Issue"},
]

# %%
complaints_data += [
    # Complaint 40 – Customer Support Issue
    {"Complaint Text": "Codecademy support is unresponsive about my course access issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I can't get a hold of anyone at Codecademy to help me access my course.", "Category": "Customer Support Issue"},
    {"Complaint Text": "My requests to Codecademy support about not being able to access a course are being ignored.", "Category": "Customer Support Issue"},
    {"Complaint Text": "There's no way to contact Codecademy support for help with my access problem.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I'm locked out of my course and Codecademy support is not responding.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy's customer service is unreachable, and I need access to my course.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Tried multiple times to contact Codecademy support about a course access error, with no luck.", "Category": "Customer Support Issue"},
    {"Complaint Text": "It's impossible to get support from Codecademy to resolve my course access.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy support has not replied to my ticket about being unable to access my course.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I need help with course access, but Codecademy's support team is missing in action.", "Category": "Customer Support Issue"},
    {"Complaint Text": "No response from Codecademy support regarding my inability to get into my paid course.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I am unable to get a response from Codecademy to fix my course access.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy has provided no support for my problem accessing a course.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Customer support at Codecademy is nonexistent; I can't access what I paid for.", "Category": "Customer Support Issue"},
    {"Complaint Text": "My emails to Codecademy support about fixing course access go unanswered.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Cannot get in touch with a human at Codecademy to solve my course access issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I'm stuck without course access because Codecademy support won't reply.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy's support system is failing me; I can't get into my course.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Locked out of my course and can't get any assistance from Codecademy.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I've been trying to reach Codecademy support for days about my course access with no success.", "Category": "Customer Support Issue"},
]

# %%
complaints_data += [
    # Complaint 41 – Course Access Issue
    {"Complaint Text": "I paid for a Codecademy course but I can't access it.", "Category": "Course Access Issue"},
    {"Complaint Text": "My Codecademy account shows I'm enrolled, but the course is locked.", "Category": "Course Access Issue"},
    {"Complaint Text": "After making the payment, Codecademy is not letting me into my course.", "Category": "Course Access Issue"},
    {"Complaint Text": "I'm getting an error when I try to start my paid course on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy took my money but didn't unlock the course content.", "Category": "Course Access Issue"},
    {"Complaint Text": "My new Codecademy course is not appearing in my dashboard after purchase.", "Category": "Course Access Issue"},
    {"Complaint Text": "I have a receipt from Codecademy but no access to the course I bought.", "Category": "Course Access Issue"},
    {"Complaint Text": "The course I enrolled in on Codecademy is still showing as unavailable.", "Category": "Course Access Issue"},
    {"Complaint Text": "Despite a successful payment, I am denied access to my Codecademy course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy's platform won't let me start the course I just paid for.", "Category": "Course Access Issue"},
    {"Complaint Text": "I'm locked out of my new Codecademy course even though my payment went through.", "Category": "Course Access Issue"},
    {"Complaint Text": "There's an issue preventing me from accessing my recently purchased Codecademy course.", "Category": "Course Access Issue"},
    {"Complaint Text": "My enrollment in the Codecademy course is confirmed, but access is blocked.", "Category": "Course Access Issue"},
    {"Complaint Text": "I can't begin my studies on Codecademy because the course won't load post-payment.", "Category": "Course Access Issue"},
    {"Complaint Text": "Paid for a subscription, but Codecademy course access is restricted.", "Category": "Course Access Issue"},
    {"Complaint Text": "My Codecademy library isn't updating with the course I purchased.", "Category": "Course Access Issue"},
    {"Complaint Text": "Having trouble accessing my Codecademy course materials after I paid.", "Category": "Course Access Issue"},
    {"Complaint Text": "The link to my new Codecademy course is broken or inaccessible.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy's system has not granted me access to the course after payment.", "Category": "Course Access Issue"},
    {"Complaint Text": "I am a paid user but cannot get into the Codecademy course I signed up for.", "Category": "Course Access Issue"},
]

# %%
complaints_data += [
    # Complaint 42 – Refund Issue
    {"Complaint Text": "Codecademy support is not responding to my multiple refund requests.", "Category": "Refund Issue"},
    {"Complaint Text": "I've asked for a refund several times from Codecademy and have been ignored.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund requests to Codecademy are being completely disregarded.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy has not acknowledged any of my requests for a refund.", "Category": "Refund Issue"},
    {"Complaint Text": "Despite repeated attempts, Codecademy support has not processed my refund.", "Category": "Refund Issue"},
    {"Complaint Text": "I've sent numerous emails to Codecademy about a refund with no reply.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy is giving me the silent treatment regarding my refund request.", "Category": "Refund Issue"},
    {"Complaint Text": "No one at Codecademy will answer my queries about getting my money back.", "Category": "Refund Issue"},
    {"Complaint Text": "My case for a refund has been repeatedly overlooked by Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "I keep asking for a refund from Codecademy, but I get no response.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy's support team is ignoring all my communication about a refund.", "Category": "Refund Issue"},
    {"Complaint Text": "It feels impossible to get a refund from Codecademy because they ignore my requests.", "Category": "Refund Issue"},
    {"Complaint Text": "I've followed up many times on my refund from Codecademy to no avail.", "Category": "Refund Issue"},
    {"Complaint Text": "My pleas for a refund are falling on deaf ears at Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy has failed to act on my persistent refund requests.", "Category": "Refund Issue"},
    {"Complaint Text": "All my attempts to get a refund from Codecademy have been met with silence.", "Category": "Refund Issue"},
    {"Complaint Text": "The support channel at Codecademy is unresponsive to refund inquiries.", "Category": "Refund Issue"},
    {"Complaint Text": "I am being ignored by Codecademy after requesting a refund multiple times.", "Category": "Refund Issue"},
    {"Complaint Text": "There has been no action or reply from Codecademy on my repeated refund requests.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy support has gone dark ever since I asked for a refund.", "Category": "Refund Issue"},
]

# %%
complaints_data += [
    # Complaint 43 – Instructor Issue
    {"Complaint Text": "The Codecademy instructor completely missed key topics mentioned in the syllabus.", "Category": "Instructor Issue"},
    {"Complaint Text": "Important subjects were left out of the Codecademy course by the instructor.", "Category": "Instructor Issue"},
    {"Complaint Text": "My Codecademy course instructor skipped over crucial learning modules.", "Category": "Instructor Issue"},
    {"Complaint Text": "The person teaching the Codecademy course failed to cover essential content.", "Category": "Instructor Issue"},
    {"Complaint Text": "There are gaps in the Codecademy course because the instructor omitted topics.", "Category": "Instructor Issue"},
    {"Complaint Text": "The Codecademy instructor did not teach all the promised material.", "Category": "Instructor Issue"},
    {"Complaint Text": "Essential concepts were glossed over or entirely skipped by the Codecademy instructor.", "Category": "Instructor Issue"},
    {"Complaint Text": "I feel the Codecademy course was incomplete as the instructor skipped parts.", "Category": "Instructor Issue"},
    {"Complaint Text": "The Codecademy instructor bypassed fundamental topics that were supposed to be covered.", "Category": "Instructor Issue"},
    {"Complaint Text": "My learning was hindered because the Codecademy instructor avoided key areas.", "Category": "Instructor Issue"},
    {"Complaint Text": "The teacher for my Codecademy course jumped over vital sections of the curriculum.", "Category": "Instructor Issue"},
    {"Complaint Text": "Not all topics from the course description were taught by the Codecademy instructor.", "Category": "Instructor Issue"},
    {"Complaint Text": "The Codecademy course felt rushed as the instructor skipped important information.", "Category": "Instructor Issue"},
    {"Complaint Text": "We didn't cover some necessary topics in the Codecademy course.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor's teaching on Codecademy was inadequate and missed core subjects.", "Category": "Instructor Issue"},
    {"Complaint Text": "I am disappointed the Codecademy instructor did not address all the course objectives.", "Category": "Instructor Issue"},
    {"Complaint Text": "Critical information was missing from the lectures in my Codecademy course.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor failed to provide a comprehensive lesson, skipping key points on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "I feel unprepared because the Codecademy instructor didn't cover everything.", "Category": "Instructor Issue"},
    {"Complaint Text": "The curriculum was not fully delivered by the instructor in the Codecademy course.", "Category": "Instructor Issue"},
]

# %%
complaints_data += [
    # Complaint 44 – Customer Support Issue
    {"Complaint Text": "Codecademy support told me my refund was processed, but it wasn't.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I was given false information about my refund status by Codecademy's support team.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The refund status provided by Codecademy support was inaccurate.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy support misled me about when I would receive my refund.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The information I got from Codecademy support regarding my refund was wrong.", "Category": "Customer Support Issue"},
    {"Complaint Text": "A Codecademy support agent gave me an incorrect update on my refund.", "Category": "Customer Support Issue"},
    {"Complaint Text": "My refund has not arrived, despite Codecademy support confirming it was sent.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I was misinformed by Codecademy's support about the completion of my refund.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The status of my refund from Codecademy support turned out to be false.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy support claimed my refund was complete, but I have not received it.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Received conflicting and incorrect information from Codecademy support about my refund.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The support team at Codecademy provided a misleading status for my refund request.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I cannot trust the refund updates from Codecademy support.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy's support staff gave me wrong details about my refund's progress.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The refund information from Codecademy's help desk was unreliable and incorrect.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I was assured by Codecademy support that my refund was done, which was untrue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "There is a discrepancy between what Codecademy support said and my actual refund status.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The customer service agent at Codecademy reported my refund status incorrectly.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I am still waiting for a refund that Codecademy support said was already processed.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The update I received from Codecademy support about my refund was factually wrong.", "Category": "Customer Support Issue"},
]

# %%
complaints_data += [
    # Complaint 45 – Payment Issue (Auto-renewal)
    {"Complaint Text": "Codecademy renewed my subscription without any warning or notification.", "Category": "Payment Issue"},
    {"Complaint Text": "I was charged for renewal by Codecademy with no prior reminder.", "Category": "Payment Issue"},
    {"Complaint Text": "My Codecademy subscription auto-renewed, and a payment was taken without a heads-up.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy didn't send a reminder email before my renewal payment was processed.", "Category": "Payment Issue"},
    {"Complaint Text": "The auto-renewal payment taken by Codecademy was a complete surprise.", "Category": "Payment Issue"},
    {"Complaint Text": "No alert from Codecademy before they charged me for another subscription period.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy processed a renewal payment without my explicit, recent consent.", "Category": "Payment Issue"},
    {"Complaint Text": "Payment for another term was taken by Codecademy without notice.", "Category": "Payment Issue"},
    {"Complaint Text": "I was not informed about the upcoming auto-renewal payment on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "My card was charged by Codecademy for renewal unexpectedly.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy auto-renewed my plan and took payment without informing me beforehand.", "Category": "Payment Issue"},
    {"Complaint Text": "A renewal payment was deducted from my account by Codecademy without any alert.", "Category": "Payment Issue"},
    {"Complaint Text": "Didn't receive any notification before Codecademy charged me for renewal.", "Category": "Payment Issue"},
    {"Complaint Text": "The auto-renewal payment from Codecademy occurred without warning.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy failed to notify me before taking the annual renewal payment.", "Category": "Payment Issue"},
    {"Complaint Text": "Surprised by a renewal payment from Codecademy on my bank statement.", "Category": "Payment Issue"},
    {"Complaint Text": "No communication from Codecademy before my subscription was auto-renewed and charged.", "Category": "Payment Issue"},
    {"Complaint Text": "The payment for my Codecademy renewal was processed silently.", "Category": "Payment Issue"},
    {"Complaint Text": "I wasn't given a chance to opt-out before Codecademy took the renewal payment.", "Category": "Payment Issue"},
    {"Complaint Text": "An unexpected renewal payment was charged to my account by Codecademy.", "Category": "Payment Issue"},
]

# %%
complaints_data += [
    # Complaint 46 – Customer Support Issue (Availability)
    {"Complaint Text": "There is no after-hours customer support available from Codecademy.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I couldn't get help from Codecademy support in the evening or on weekends.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy customer service is only available during a very limited time window.", "Category": "Customer Support Issue"},
    {"Complaint Text": "No weekend or holiday support is offered by Codecademy.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I needed help outside of standard business hours, but Codecademy support was closed.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy does not provide 24/7 customer support, which is inconvenient.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Unable to reach Codecademy support due to time zone differences.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The support hours for Codecademy are extremely restrictive.", "Category": "Customer Support Issue"},
    {"Complaint Text": "It's impossible to get technical help from Codecademy late at night.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy customer care operates on a schedule that doesn't work for me.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I had an urgent issue, but Codecademy support had already closed for the day.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Support from Codecademy is not accessible for users in different international time zones.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The lack of extended support hours at Codecademy is a major problem.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy offers no support options outside of a 9-to-5 workday.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Contacting Codecademy for support is only possible during their specific business hours.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy needs to offer support for users outside of standard North American working hours.", "Category": "Customer Support Issue"},
    {"Complaint Text": "No assistance is available from Codecademy during early mornings or late nights.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The operational hours of Codecademy's support team are not flexible.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I can only study at night, but Codecademy provides no support during those hours.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Reached out for help on a Saturday and got an auto-reply that Codecademy support was closed.", "Category": "Customer Support Issue"},
]

# %%
complaints_data += [
    # Complaint 47 – Course Access Issue (Progress Tracking)
    {"Complaint Text": "My progress in the Codecademy course is not being saved correctly.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy keeps marking lessons I have already finished as incomplete.", "Category": "Course Access Issue"},
    {"Complaint Text": "The checkmarks for completed lessons on Codecademy keep disappearing.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy's system is not registering the lessons I have completed.", "Category": "Course Access Issue"},
    {"Complaint Text": "I have to redo lessons on Codecademy because my progress isn't being tracked.", "Category": "Course Access Issue"},
    {"Complaint Text": "The course progress bar on Codecademy is stuck and won't update.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy has lost track of which parts of the course I have already finished.", "Category": "Course Access Issue"},
    {"Complaint Text": "The platform fails to save my completion status for modules on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "My completed units on Codecademy are being shown as 'not started'.", "Category": "Course Access Issue"},
    {"Complaint Text": "There's a bug in Codecademy where my course progress is not recorded.", "Category": "Course Access Issue"},
    {"Complaint Text": "I am unable to move forward because Codecademy thinks I haven't completed the prerequisite lesson.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecad's system does not reflect my actual progress through the course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Every time I log in, my lesson progress on Codecademy has been reset.", "Category": "Course Access Issue"},
    {"Complaint Text": "The progress tracking system on Codecademy is broken and won't save my work.", "Category": "Course Access Issue"},
    {"Complaint Text": "My completed lessons are not being recognized by the Codecademy learning platform.", "Category": "Course Access Issue"},
    {"Complaint Text": "I'm losing my place in the course because Codecademy fails to track my progress.", "Category": "Course Access Issue"},
    {"Complaint Text": "The platform is not acknowledging my lesson completions, halting my progress.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy is failing to track my journey through the course materials.", "Category": "Course Access Issue"},
    {"Complaint Text": "I have to manually keep track of my lessons because Codecademy's system is faulty.", "Category": "Course Access Issue"},
    {"Complaint Text": "My course dashboard on Codecademy does not show my true progress.", "Category": "Course Access Issue"},
]

# %%
complaints_data += [
    # Complaint 48 – Refund Issue
    {"Complaint Text": "Codecademy denied my refund request and gave no proper explanation.", "Category": "Refund Issue"},
    {"Complaint Text": "My request for a refund from Codecademy was rejected arbitrarily.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy refused to issue a refund and did not provide a valid cause.", "Category": "Refund Issue"},
    {"Complaint Text": "I was denied a refund by Codecademy without any justification.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund was rejected by Codecademy for no good reason.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy provided a flimsy excuse for rejecting my refund claim.", "Category": "Refund Issue"},
    {"Complaint Text": "The rejection of my refund request from Codecademy was unsubstantiated.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy will not refund my money and won't tell me why.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund request, which met the policy terms, was denied by Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "Received a rejection for my refund from Codecademy with no clear reason.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy turned down my refund request without a legitimate basis.", "Category": "Refund Issue"},
    {"Complaint Text": "The reason Codecademy gave for my refund denial was not valid.", "Category": "Refund Issue"},
    {"Complaint Text": "I am disputing a refund rejection from Codecademy that was not justified.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy summarily rejected my refund without looking into the issue.", "Category": "Refund Issue"},
    {"Complaint Text": "I am eligible for a refund, but Codecademy rejected my request anyway.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund request was unfairly denied by Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy closed my refund case with a rejection but no valid details.", "Category": "Refund Issue"},
    {"Complaint Text": "The denial of my refund from Codecademy seems baseless.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy support refused my refund with a generic, unhelpful response.", "Category": "Refund Issue"},
    {"Complaint Text": "I'm fighting a refund rejection from Codecademy that lacks a valid reason.", "Category": "Refund Issue"},
]

# %%
complaints_data += [
    # Complaint 49 – Customer Support Issue
    {"Complaint Text": "I received contradictory advice from two different Codecademy support agents.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy's support team gave me conflicting information about how to fix my issue.", "Category": "Customer Support Issue"},
    {"Complaint Text": "One support agent at Codecademy told me one thing, and another told me the opposite.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The solutions offered by Codecademy support were inconsistent.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I am confused because the Codecademy support team keeps giving me different answers.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy's customer service provided solutions that conflicted with each other.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The advice from Codecademy support has been inconsistent and unhelpful.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I got two different solutions from the Codecademy helpdesk, and neither worked.", "Category": "Customer Support Issue"},
    {"Complaint Text": "There is no consistency in the answers provided by Codecademy support.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The support team at Codecademy seems confused, they gave me conflicting guidance.", "Category": "Customer Support Issue"},
    {"Complaint Text": "My support ticket with Codecademy has contradictory responses from the staff.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Every time I contact Codecademy support, I get a different story.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The lack of consistency from the Codecademy support team is frustrating.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy support provided a solution, then another agent said that solution was wrong.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Dealing with Codecademy support is impossible when they provide conflicting resolutions.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I was given opposing instructions by the Codecademy customer support team.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The guidance from Codecademy's support staff was contradictory.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I'm stuck in a loop because Codecademy support offers conflicting advice.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Different members of the Codecademy support team are not on the same page.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The resolutions suggested by Codecademy support were mutually exclusive.", "Category": "Customer Support Issue"},
]

# %%
complaints_data += [
    # Complaint 50 – Content Quality Issue
    {"Complaint Text": "The exercises on Codecademy lack sufficient examples to understand the concept.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy's course material is missing crucial explanations for its exercises.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I am struggling with Codecademy exercises because there are no clear examples.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The learning exercises on Codecademy need better explanations.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Key examples are omitted from the Codecademy exercise descriptions.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The content quality is poor; Codecademy exercises don't have enough context.", "Category": "Content Quality Issue"},
    {"Complaint Text": "It's hard to complete the exercises on Codecademy without proper explanations.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy course fails to provide illustrative examples for its practice problems.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Many exercises in the Codecademy course are poorly explained.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I can't solve the Codecademy exercises due to a lack of clear instructions and examples.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The educational content for Codecademy exercises is inadequate.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy needs to add more worked examples to its exercises.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The exercises assume prior knowledge that wasn't covered in the Codecademy lessons.", "Category": "Content Quality Issue"},
    {"Complaint Text": "There's a significant lack of detail and examples in the Codecademy exercises.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The practice problems on Codecademy are confusing because they lack explanations.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy's lesson quality suffers from a lack of examples in the exercises.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The provided exercises on Codecademy are not self-contained and miss vital information.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I wish the Codecademy exercises had more detailed walkthroughs and examples.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The gap between the lessons and the exercises on Codecademy is too large due to missing examples.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy's exercises are difficult to approach without more explanatory content.", "Category": "Content Quality Issue"},
]

# %%
complaints_data += [
    # Complaint 51 – Misleading Course Description
    {"Complaint Text": "Codecademy listed the course as 'beginner' but it was actually very advanced.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The difficulty level advertised for the Codecademy course was completely wrong.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I was not prepared for how difficult the Codecademy course was, based on its description.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course on Codecademy was much harder than its 'intermediate' label suggested.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy misled me about the prerequisite knowledge needed for this course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The advertised difficulty on Codecademy did not match the challenging reality of the course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "This Codecademy course should not be labeled as introductory; it's much more complex.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I found the Codecademy course significantly more difficult than advertised.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course description on Codecademy gave a false impression of its difficulty.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy needs to re-evaluate the difficulty rating for this course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I signed up for a beginner course on Codecademy and found it impossibly hard.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The difficulty ramped up way too quickly in the Codecademy course for its advertised level.", "Category": "Misleading Course Description"},
    {"Complaint Text": "This is a classic case of misrepresenting course difficulty on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's description of the course as 'easy' was inaccurate.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I feel the difficulty level was understated in the Codecademy course marketing.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course content on Codecademy was far more advanced than the label indicated.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The difficulty of this Codecademy course is much higher than what is stated on the syllabus.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's course was not suitable for beginners as it was advertised.", "Category": "Misleading Course Description"},
    {"Complaint Text": "There's a huge mismatch between the promised and actual difficulty of the Codecademy course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I struggled immensely because Codecademy misrepresented how hard the course would be.", "Category": "Misleading Course Description"},
]

# %%
complaints_data += [
    # Complaint 52 – Refund Issue
    {"Complaint Text": "My refund from Codecademy is taking much longer than they said it would.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy has not processed my refund within the timeline they promised.", "Category": "Refund Issue"},
    {"Complaint Text": "I am still waiting for my refund from Codecademy, well past the stated processing time.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund from Codecademy was not issued in the number of days they guaranteed.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy is late in issuing my refund.", "Category": "Refund Issue"},
    {"Complaint Text": "It has been weeks and my Codecademy refund, promised in 5-7 days, has not arrived.", "Category": "Refund Issue"},
    {"Complaint Text": "The promised timeline for my Codecademy refund has expired and I still have no money.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy failed to meet their own deadline for processing my refund.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund is overdue based on the timeline provided by Codecademy support.", "Category": "Refund Issue"},
    {"Complaint Text": "Why is my Codecademy refund taking longer than the advertised 10 business days?", "Category": "Refund Issue"},
    {"Complaint Text": "The processing of my refund by Codecademy has been severely delayed.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy exceeded the timeframe they gave me for my refund.", "Category": "Refund Issue"},
    {"Complaint Text": "I am concerned about the delay in receiving my refund from Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund process at Codecademy is much slower than they claim.", "Category": "Refund Issue"},
    {"Complaint Text": "My money has been held by Codecademy longer than their refund policy states.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy has not honored the refund timeline they communicated to me.", "Category": "Refund Issue"},
    {"Complaint Text": "Still no sign of my refund from Codecademy, and the promised date has passed.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund from Codecademy is being delayed without any explanation.", "Category": "Refund Issue"},
    {"Complaint Text": "I was told my refund would be quick, but Codecademy is taking forever.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy needs to be held accountable for their delayed refund processing.", "Category": "Refund Issue"},
]

# %%
complaints_data += [
    # Complaint 52 – Refund Issue
    {"Complaint Text": "My refund from Codecademy is taking much longer than they said it would.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy has not processed my refund within the timeline they promised.", "Category": "Refund Issue"},
    {"Complaint Text": "I am still waiting for my refund from Codecademy, well past the stated processing time.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund from Codecademy was not issued in the number of days they guaranteed.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy is late in issuing my refund.", "Category": "Refund Issue"},
    {"Complaint Text": "It has been weeks and my Codecademy refund, promised in 5-7 days, has not arrived.", "Category": "Refund Issue"},
    {"Complaint Text": "The promised timeline for my Codecademy refund has expired and I still have no money.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy failed to meet their own deadline for processing my refund.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund is overdue based on the timeline provided by Codecademy support.", "Category": "Refund Issue"},
    {"Complaint Text": "Why is my Codecademy refund taking longer than the advertised 10 business days?", "Category": "Refund Issue"},
    {"Complaint Text": "The processing of my refund by Codecademy has been severely delayed.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy exceeded the timeframe they gave me for my refund.", "Category": "Refund Issue"},
    {"Complaint Text": "I am concerned about the delay in receiving my refund from Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund process at Codecademy is much slower than they claim.", "Category": "Refund Issue"},
    {"Complaint Text": "My money has been held by Codecademy longer than their refund policy states.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy has not honored the refund timeline they communicated to me.", "Category": "Refund Issue"},
    {"Complaint Text": "Still no sign of my refund from Codecademy, and the promised date has passed.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund from Codecademy is being delayed without any explanation.", "Category": "Refund Issue"},
    {"Complaint Text": "I was told my refund would be quick, but Codecademy is taking forever.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy needs to be held accountable for their delayed refund processing.", "Category": "Refund Issue"},
]

# %%
complaints_data += [
    # Complaint 53 – Payment Issue
    {"Complaint Text": "My payment for a Codecademy subscription keeps failing for no reason.", "Category": "Payment Issue"},
    {"Complaint Text": "I cannot subscribe to Codecademy because my transaction is repeatedly declined.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy's payment system is not working; my card keeps getting rejected.", "Category": "Payment Issue"},
    {"Complaint Text": "I'm trying to pay for a course on Codecademy, but the transaction fails every time.", "Category": "Payment Issue"},
    {"Complaint Text": "There seems to be an error with Codecademy's payment gateway.", "Category": "Payment Issue"},
    {"Complaint Text": "I've tried multiple cards, but I'm unable to complete my payment on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Every attempt to pay on Codecademy results in a transaction failure message.", "Category": "Payment Issue"},
    {"Complaint Text": "The checkout process on Codecademy is broken; it won't accept my payment.", "Category": "Payment Issue"},
    {"Complaint Text": "I want to purchase a membership, but Codecademy's site won't process my payment.", "Category": "Payment Issue"},
    {"Complaint Text": "My bank says the issue is not on their end, but Codecademy payments keep failing.", "Category": "Payment Issue"},
    {"Complaint Text": "Getting constant transaction errors when trying to pay Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy is preventing me from buying a subscription due to payment failures.", "Category": "Payment Issue"},
    {"Complaint Text": "The payment form on Codecademy is giving me an error and I can't subscribe.", "Category": "Payment Issue"},
    {"Complaint Text": "I am unable to enroll in a course because of persistent payment issues on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "My payment is not going through on the Codecademy platform.", "Category": "Payment Issue"},
    {"Complaint Text": "Repeated attempts to pay Codecademy have been unsuccessful.", "Category": "Payment Issue"},
    {"Complaint Text": "There is a problem with the Codecademy billing system that is blocking my payment.", "Category": "Payment Issue"},
    {"Complaint Text": "I can't finalize my purchase on Codecademy due to a recurring transaction error.", "Category": "Payment Issue"},
    {"Complaint Text": "I'm stuck in a payment loop on Codecademy where the transaction always fails.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy's website is rejecting my valid payment method.", "Category": "Payment Issue"},
]

# %%
complaints_data += [
    # Complaint 54 – Technical Glitch
    {"Complaint Text": "The Codecademy website freezes every time I try to take a quiz.", "Category": "Technical Glitch"},
    {"Complaint Text": "I can't complete any quizzes on Codecademy because the page becomes unresponsive.", "Category": "Technical Glitch"},
    {"Complaint Text": "The quiz interface on Codecademy constantly hangs and stops working.", "Category": "Technical Glitch"},
    {"Complaint Text": "My web browser locks up whenever I am on a Codecademy quiz page.", "Category": "Technical Glitch"},
    {"Complaint Text": "Every time I attempt a test on Codecademy, the screen freezes solid.", "Category": "Technical Glitch"},
    {"Complaint Text": "The Codecademy platform crashes specifically during quizzes.", "Category": "Technical Glitch"},
    {"Complaint Text": "I am unable to submit quiz answers because the page on Codecademy is frozen.", "Category": "Technical Glitch"},
    {"Complaint Text": "There is a recurring technical issue where Codecademy quizzes freeze mid-way.", "Category": "Technical Glitch"},
    {"Complaint Text": "The assessment section of the Codecademy platform is unusable due to freezing.", "Category": "Technical Glitch"},
    {"Complaint Text": "My quiz timed out because the Codecademy page froze and I couldn't do anything.", "Category": "Technical Glitch"},
    {"Complaint Text": "The web platform becomes non-functional when I access any quiz on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "I have to constantly refresh the page as the quizzes on Codecademy freeze up.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy's quizzes have a bug that causes the entire browser tab to stop working.", "Category": "Technical Glitch"},
    {"Complaint Text": "The quiz module on Codecademy is broken and freezes my computer.", "Category": "Technical Glitch"},
    {"Complaint Text": "Trying to take a quiz on Codecademy consistently leads to a frozen tab.", "Category": "Technical Glitch"},
    {"Complaint Text": "I'm experiencing constant freezing issues specifically on Codecademy's quiz pages.", "Category": "Technical Glitch"},
    {"Complaint Text": "The Codecademy platform is unable to handle quizzes without freezing.", "Category": "Technical Glitch"},
    {"Complaint Text": "I keep losing my progress in quizzes because the Codecademy site freezes.", "Category": "Technical Glitch"},
    {"Complaint Text": "The interactive quizzes on Codecademy are not stable and frequently freeze.", "Category": "Technical Glitch"},
    {"Complaint Text": "There's a major glitch causing quiz pages on the Codecademy website to lock up.", "Category": "Technical Glitch"},
]

# %%
complaints_data += [
    # Complaint 55 – Content Quality Issue
    {"Complaint Text": "The official solutions for Codecademy exercises contain errors.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I tried the provided solution code on Codecademy, and it doesn't work.", "Category": "Content Quality Issue"},
    {"Complaint Text": "There are bugs in the solution files offered by Codecademy.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The sample solution code on Codecademy is faulty and fails to run.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I'm learning the wrong things because Codecademy's solution code is broken.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The answer keys for the coding exercises on Codecademy have bugs.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy's suggested solutions for projects are not functional.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The code provided by Codecademy as a solution is buggy.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I can't trust the learning material when the official Codecademy solutions are incorrect.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The 'Get Solution' feature on Codecademy often provides code that has errors.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Many of the official code solutions on Codecademy are outdated or have bugs.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The quality of Codecademy's content is questionable as their own solutions are flawed.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I ran the exact solution from Codecademy and it threw an error.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The example solutions in the Codecademy course are unreliable.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy needs to quality-check their own solutions, as many are bug-ridden.", "Category": "Content Quality Issue"},
    {"Complaint Text": "It's confusing when the provided solution code on Codecademy doesn't pass the exercise.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The solution code for several lessons on Codecademy is simply wrong.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I have found multiple bugs in the official answer code on Codecademy.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The final project solution provided by Codecademy did not work as intended.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I'm wasting time debugging Codecademy's own buggy solution code.", "Category": "Content Quality Issue"},
]

# %%
complaints_data += [
    # Complaint 56 – Misleading Course Description
    {"Complaint Text": "The Codecademy course advertised live sessions, but none ever happened.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I was promised live instructor sessions in my Codecademy course, but they were cancelled.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The live events that were part of the Codecademy course package never took place.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy failed to deliver the live sessions that were a key feature of the course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I signed up for a Codecademy course based on the promise of live sessions that weren't held.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course description on Codecademy mentioned live sessions, which was false advertising.", "Category": "Misleading Course Description"},
    {"Complaint Text": "We were supposed to have weekly live sessions in our Codecademy course, but they never occurred.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The promised live Q&A sessions with the instructor on Codecademy were never scheduled.", "Category": "Misleading Course Description"},
    {"Complaint Text": "My Codecademy course did not include the live sessions that were listed in its features.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I feel misled because the live component of the Codecademy course was never provided.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The syllabus on Codecademy promised live interactive sessions, but we only got pre-recorded videos.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy did not honor its commitment to provide live sessions for this course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The live workshops advertised for the Codecademy path were never conducted.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I'm disappointed that the promised live sessions on Codecademy were a no-show.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course was marketed by Codecademy with live sessions, but they were nonexistent.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Part of the reason I paid for the Codecademy course was for live sessions that I never got.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's failure to conduct the promised live sessions is a breach of the course description.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course overview on Codecademy was deceptive about the inclusion of live sessions.", "Category": "Misleading Course Description"},
    {"Complaint Text": "All the scheduled live sessions for my Codecademy course were cancelled without explanation.", "Category": "Misleading Course Description"},
    {"Complaint Text": "We were cheated out of the live sessions that were supposed to be part of the Codecademy course.", "Category": "Misleading Course Description"},
]

# %%
complaints_data += [
    # Complaint 57 – Certificate Issue
    {"Complaint Text": "I finished my course, but the certificate link on Codecademy is broken.", "Category": "Certificate Issue"},
    {"Complaint Text": "I am unable to access my certificate from the Codecademy platform.", "Category": "Certificate Issue"},
    {"Complaint Text": "The link to download my Codecademy certificate leads to an error page.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy is not allowing me to view or download my completion certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "My certificate of completion is inaccessible within the Codecademy dashboard.", "Category": "Certificate Issue"},
    {"Complaint Text": "When I click the link for my certificate on Codecademy, nothing happens.", "Category": "Certificate Issue"},
    {"Complaint Text": "There seems to be a glitch preventing me from accessing my Codecademy certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "I have completed all requirements, but the Codecademy certificate link is greyed out.", "Category": "Certificate Issue"},
    {"Complaint Text": "The URL for my Codecademy certificate appears to be dead.", "Category": "Certificate Issue"},
    {"Complaint Text": "I cannot retrieve my certificate because the link on the Codecademy site is faulty.", "Category": "Certificate Issue"},
    {"Complaint Text": "I'm getting a '404 Not Found' error on my Codecademy certificate link.", "Category": "Certificate Issue"},
    {"Complaint Text": "The link provided by Codecademy to claim my certificate is not working.", "Category": "Certificate Issue"},
    {"Complaint Text": "I'm blocked from accessing my earned certificate on the Codecademy platform.", "Category": "Certificate Issue"},
    {"Complaint Text": "My Codecademy profile shows the course as complete, but the certificate link is invalid.", "Category": "Certificate Issue"},
    {"Complaint Text": "The platform is not generating an accessible link for my Codecademy certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "I need to share my certificate, but the link from Codecademy is not functional.", "Category": "Certificate Issue"},
    {"Complaint Text": "Every attempt to open my certificate on Codecademy fails.", "Category": "Certificate Issue"},
    {"Complaint Text": "The certificate is visible on my dashboard, but the link to open it is broken on Codecademy.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy's system has failed to provide a working link to my certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "I'm unable to get my proof of completion because the Codecademy certificate link is inaccessible.", "Category": "Certificate Issue"},
]

# %%
complaints_data += [
    # Complaint 58 – Misleading Course Description
    {"Complaint Text": "The skills I gained from the Codecademy course do not match the learning outcomes listed.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy made false promises about what I would be able to do after the course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The learning outcomes described by Codecademy were greatly exaggerated.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I did not achieve the stated learning objectives from the Codecademy course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course on Codecademy did not prepare me for the job roles it claimed it would.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's description of the course outcomes was misleading.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The actual results of taking the Codecademy course fell short of the advertised outcomes.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The 'What you'll learn' section for the Codecademy course was inaccurate.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I feel that Codecademy misrepresented the value and outcomes of this program.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course from Codecademy did not deliver on its promised learning outcomes.", "Category": "Misleading Course Description"},
    {"Complaint Text": "There is a significant gap between the advertised skills and the actual skills taught by Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The learning objectives on the Codecademy course page were not met by the content.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's marketing for this course promised outcomes that were not delivered.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I am unable to perform the tasks that Codecademy claimed I would master in this course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The final skills I have after this Codecademy course are not what was promised.", "Category": "Misleading Course Description"},
    {"Complaint Text": "This Codecademy course was a case of over-promising and under-delivering on outcomes.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The professional outcomes suggested by Codecademy for this course are unrealistic.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I am disappointed by the disconnect between the promised and actual learning outcomes on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course description from Codecademy set false expectations about the learning outcomes.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy needs to revise its course description to reflect the true learning outcomes.", "Category": "Misleading Course Description"},
]

# %%
complaints_data += [
    # Complaint 59 – Instructor Issue
    {"Complaint Text": "The Codecademy instructor mentioned extra resources in lectures but never shared them.", "Category": "Instructor Issue"},
    {"Complaint Text": "I did not receive the supplementary materials that the Codecademy instructor promised.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor on Codecademy failed to provide the promised cheat sheets and guides.", "Category": "Instructor Issue"},
    {"Complaint Text": "We were told we would get additional readings by the Codecademy instructor, but we never did.", "Category": "Instructor Issue"},
    {"Complaint Text": "My Codecademy course instructor did not follow through on providing extra resources.", "Category": "Instructor Issue"},
    {"Complaint Text": "The promised GitHub repository of resources from the Codecademy instructor was never provided.", "Category": "Instructor Issue"},
    {"Complaint Text": "I am missing the additional learning materials that the instructor said would be available on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor's promise of providing downloadable project files on Codecademy was not kept.", "Category": "Instructor Issue"},
    {"Complaint Text": "We are still waiting for the extra resources the Codecademy instructor mentioned weeks ago.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor on the Codecademy platform failed to upload the promised bonus content.", "Category": "Instructor Issue"},
    {"Complaint Text": "I feel let down because the Codecademy instructor did not provide the advertised resources.", "Category": "Instructor Issue"},
    {"Complaint Text": "The supplemental content promised by the teacher on Codecademy is missing.", "Category": "Instructor Issue"},
    {"Complaint Text": "My learning experience was incomplete because the Codecademy instructor withheld promised resources.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor for the Codecademy course did not deliver the extra materials as stated.", "Category": "Instructor Issue"},
    {"Complaint Text": "All the 'bonus' resources mentioned by the Codecademy instructor were never actually given.", "Category": "Instructor Issue"},
    {"Complaint Text": "I'm unable to find the additional resources the instructor said would be in the final module on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "The Codecademy course is less valuable without the promised resources from the instructor.", "Category": "Instructor Issue"},
    {"Complaint Text": "Our instructor on Codecademy made promises about extra content that they did not keep.", "Category": "Instructor Issue"},
    {"Complaint Text": "There was no follow-up from the Codecademy instructor regarding the promised supplementary docs.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor mentioned a list of helpful links would be provided on Codecademy, but it never was.", "Category": "Instructor Issue"},
]

# %%
complaints_data += [
    # Complaint 60 – Instructor Issue
    {"Complaint Text": "The Codecademy instructor never answered any questions in the course forums.", "Category": "Instructor Issue"},
    {"Complaint Text": "There was absolutely no instructor presence in the Codecademy discussion section.", "Category": "Instructor Issue"},
    {"Complaint Text": "My questions posted on the discussion board were completely ignored by the Codecademy instructor.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor for my Codecademy course was completely inactive and absent from the Q&A forums.", "Category": "Instructor Issue"},
    {"Complaint Text": "We received no support or guidance from the instructor in the Codecademy community forums.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor's participation in the student discussion boards was nonexistent.", "Category": "Instructor Issue"},
    {"Complaint Text": "It was impossible to get help from the instructor on the Codecademy forums.", "Category": "Instructor Issue"},
    {"Complaint Text": "The Codecademy instructor did not engage with students in the designated discussion area.", "Category": "Instructor Issue"},
    {"Complaint Text": "I posted a question a week ago, and the Codecademy instructor still has not replied.", "Category": "Instructor Issue"},
    {"Complaint Text": "The discussion forums for the Codecademy course seem to be unmonitored by the instructor.", "Category": "Instructor Issue"},
    {"Complaint Text": "There was a severe lack of instructor involvement in the Codecademy course discussions.", "Category": "Instructor Issue"},
    {"Complaint Text": "The designated instructor for the Codecademy course was absent from the community forums.", "Category": "Instructor Issue"},
    {"Complaint Text": "Students were left to help each other because the Codecademy instructor was not active.", "Category": "Instructor Issue"},
    {"Complaint Text": "The promise of instructor support in the forums was not met on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "The course instructor on the Codecademy platform never interacted with a single student post.", "Category": "Instructor Issue"},
    {"Complaint Text": "I have seen zero activity from the instructor on the course's official discussion board.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor's role in the Codecademy discussion forum was completely passive.", "Category": "Instructor Issue"},
    {"Complaint Text": "We had no guidance from our instructor in the Codecademy community discussions.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor for my course on Codecademy appears to have abandoned the discussion boards.", "Category": "Instructor Issue"},
    {"Complaint Text": "Getting a response from the instructor in the Codecademy forums is not possible.", "Category": "Instructor Issue"},
]

# %%
len(complaints_data)
# Out:
# 960

# %%
complaints_data += [
    # Complaint 61 – Technical Glitch (Projects)
    {"Complaint Text": "I can't get the projects on Codecademy to load; the page just hangs.", "Category": "Technical Glitch"},
    {"Complaint Text": "None of my changes to Codecademy projects are being saved.", "Category": "Technical Glitch"},
    {"Complaint Text": "The project workspace on Codecademy is broken and will not load.", "Category": "Technical Glitch"},
    {"Complaint Text": "I keep losing all my work because Codecademy projects refuse to save.", "Category": "Technical Glitch"},
    {"Complaint Text": "There's a technical issue preventing the project environments from loading on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy's platform fails to save any of the progress I make on my projects.", "Category": "Technical Glitch"},
    {"Complaint Text": "The project editor on Codecademy is perpetually stuck on a loading screen.", "Category": "Technical Glitch"},
    {"Complaint Text": "I am unable to save my project code on the Codecademy website due to a bug.", "Category": "Technical Glitch"},
    {"Complaint Text": "The guided projects on Codecademy are inaccessible due to a loading error.", "Category": "Technical Glitch"},
    {"Complaint Text": "My project work keeps disappearing because the save function on Codecademy is failing.", "Category": "Technical Glitch"},
    {"Complaint Text": "The interactive project sessions on Codecademy won't launch or open.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy's system is not retaining any of the changes I make to my projects.", "Category": "Technical Glitch"},
    {"Complaint Text": "I'm experiencing a glitch where Codecademy projects either don't load or don't save.", "Category": "Technical Glitch"},
    {"Complaint Text": "The platform is unable to load the necessary project files for my course on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "Saving my progress in Codecademy projects is impossible due to a persistent bug.", "Category": "Technical Glitch"},
    {"Complaint Text": "The project interface on Codecademy hangs and won't let me save my edits.", "Category": "Technical Glitch"},
    {"Complaint Text": "I'm stuck and cannot continue my course because my Codecademy project won't load.", "Category": "Technical Glitch"},
    {"Complaint Text": "There's a recurring saving error with the portfolio projects on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy's project feature is unusable as it consistently fails to load or save.", "Category": "Technical Glitch"},
    {"Complaint Text": "I lost hours of coding work because the Codecademy project interface did not save.", "Category": "Technical Glitch"},
]

# %%
complaints_data += [
    # Complaint 62 – Technical Glitch (Login)
    {"Complaint Text": "I am unable to log into my Codecademy account, even with the correct password.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy's login page keeps giving me an error message.", "Category": "Technical Glitch"},
    {"Complaint Text": "My login attempts on the Codecademy website are constantly failing without reason.", "Category": "Technical Glitch"},
    {"Complaint Text": "I cannot access my account because the Codecademy login system appears to be broken.", "Category": "Technical Glitch"},
    {"Complaint Text": "The login process on the Codecademy website is not working for me.", "Category": "Technical Glitch"},
    {"Complaint Text": "Even after resetting my password, I am locked out of my Codecademy account.", "Category": "Technical Glitch"},
    {"Complaint Text": "A technical glitch is preventing me from logging into the Codecademy platform.", "Category": "Technical Glitch"},
    {"Complaint Text": "The Codecademy website simply will not let me sign in to my profile.", "Category": "Technical Glitch"},
    {"Complaint Text": "I appear to be stuck in a login loop on the Codecademy site.", "Category": "Technical Glitch"},
    {"Complaint Text": "I repeatedly receive a 'login failed' or 'incorrect credentials' message on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "The authentication system on Codecademy seems to be down or malfunctioning.", "Category": "Technical Glitch"},
    {"Complaint Text": "I am 100% sure my credentials are correct, but Codecademy's login still fails.", "Category": "Technical Glitch"},
    {"Complaint Text": "The Codecademy login page is either unresponsive or continuously shows an error.", "Category": "Technical Glitch"},
    {"Complaint Text": "I am unable to get past the main login screen on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "My Codecademy account has become inaccessible due to a persistent login failure.", "Category": "Technical Glitch"},
    {"Complaint Text": "Trying to sign in to my Codecademy account results in an error every single time.", "Category": "Technical Glitch"},
    {"Complaint Text": "The website is rejecting my valid login details for Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "I cannot access my paid courses because the Codecademy login is failing.", "Category": "Technical Glitch"},
    {"Complaint Text": "There is a recurring technical issue with the login functionality on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "The Codecademy platform is not recognizing my valid username and password.", "Category": "Technical Glitch"},
]

# %%
complaints_data += [
    # Complaint 63 – Payment Issue (Activation)
    {"Complaint Text": "Codecademy took my payment, but my subscription is still showing as inactive.", "Category": "Payment Issue"},
    {"Complaint Text": "My payment for Pro went through, but Codecademy hasn't activated my account.", "Category": "Payment Issue"},
    {"Complaint Text": "I paid for a Codecademy subscription, but my account was never upgraded from the free version.", "Category": "Payment Issue"},
    {"Complaint Text": "The payment was successful, but I still don't have access to paid features on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy charged my credit card but failed to activate the corresponding subscription.", "Category": "Payment Issue"},
    {"Complaint Text": "My bank statement shows the payment was made, but the subscription isn't working on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "I have an email receipt for my payment, but my Codecademy subscription remains inactive.", "Category": "Payment Issue"},
    {"Complaint Text": "After I paid, my Codecademy account is not reflecting the new Pro subscription.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy has accepted my payment, but the service has not been enabled on my account.", "Category": "Payment Issue"},
    {"Complaint Text": "My transaction was confirmed as successful, yet my Codecademy membership is not active.", "Category": "Payment Issue"},
    {"Complaint Text": "I'm locked out of Pro content on Codecademy despite having already paid for it.", "Category": "Payment Issue"},
    {"Complaint Text": "The subscription I purchased on Codecademy was never activated after my payment was processed.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy's system seems to have failed to activate my plan after taking my payment.", "Category": "Payment Issue"},
    {"Complaint Text": "I have been charged, but my Codecademy account status has not changed from 'Free' to 'Pro'.", "Category": "Payment Issue"},
    {"Complaint Text": "There is an issue where my successful payment to Codecademy did not trigger the subscription activation.", "Category": "Payment Issue"},
    {"Complaint Text": "My bank confirmed the payment to Codecademy was successful, but the subscription is not enabled.", "Category": "Payment Issue"},
    {"Complaint Text": "I am unable to access paid courses on Codecademy even though my payment was confirmed.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy needs to manually activate the subscription that I have already paid for.", "Category": "Payment Issue"},
    {"Complaint Text": "My account is stuck in a state where payment is complete but the subscription is still pending on Codecademy.", "Category": "Payment Issue"},
    {"Complaint Text": "I've paid for my Codecademy membership, why isn't it active yet?", "Category": "Payment Issue"},
]

# %%
complaints_data += [
    # Complaint 64 – Technical Glitch (App Logout)
    {"Complaint Text": "The Codecademy app keeps logging me out in the middle of a lesson.", "Category": "Technical Glitch"},
    {"Complaint Text": "I am being logged out of the Codecademy mobile app randomly and frequently.", "Category": "Technical Glitch"},
    {"Complaint Text": "The app for Codecademy does not keep me logged in, forcing me to sign in constantly.", "Category": "Technical Glitch"},
    {"Complaint Text": "I can't finish a module on the Codecademy app without being automatically logged out.", "Category": "Technical Glitch"},
    {"Complaint Text": "There's a bug in the Codecademy app that causes it to log me out unexpectedly.", "Category": "Technical Glitch"},
    {"Complaint Text": "The session on the Codecademy app expires too quickly and logs me out while I'm active.", "Category": "Technical Glitch"},
    {"Complaint Text": "I keep getting kicked out of my account on the Codecademy mobile app.", "Category": "Technical Glitch"},
    {"Complaint Text": "The Codecademy app is unusable because it logs me out every few minutes.", "Category": "Technical Glitch"},
    {"Complaint Text": "My session is not being maintained on the Codecademy app; it logs me out.", "Category": "Technical Glitch"},
    {"Complaint Text": "I'm constantly interrupted because the Codecademy app logs me out for no reason.", "Category": "Technical Glitch"},
    {"Complaint Text": "The iOS app for Codecademy has an issue where it automatically signs me out.", "Category": "Technical Glitch"},
    {"Complaint Text": "While I am actively using it, the Codecademy app logs me out of my account.", "Category": "Technical Glitch"},
    {"Complaint Text": "The automatic logout feature on the Codecademy app is far too aggressive.", "Category": "Technical Glitch"},
    {"Complaint Text": "I have to re-enter my password multiple times a day on the Codecademy app because it logs me out.", "Category": "Technical Glitch"},
    {"Complaint Text": "The Android version of the Codecademy app has a persistent auto-logout issue.", "Category": "Technical Glitch"},
    {"Complaint Text": "It is frustrating that the Codecademy app cannot maintain a stable login session.", "Category": "Technical Glitch"},
    {"Complaint Text": "The Codecademy app is not remembering my login and logs me out during use.", "Category": "Technical Glitch"},
    {"Complaint Text": "I'm experiencing a technical glitch where the Codecademy app signs me out mid-exercise.", "Category": "Technical Glitch"},
    {"Complaint Text": "My learning flow is broken by the Codecademy app's constant, automatic logouts.", "Category": "Technical Glitch"},
    {"Complaint Text": "The app for Codecademy fails to keep me authenticated for any reasonable amount of time.", "Category": "Technical Glitch"},
]

# %%
complaints_data += [
    # Complaint 65 – Content Quality Issue
    {"Complaint Text": "The course content on Codecademy was far more advanced than its 'Beginner' label suggested.", "Category": "Content Quality Issue"},
    {"Complaint Text": "There's a mismatch between the actual content difficulty and what Codecademy advertised.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The lessons in this Codecademy course are much harder than the advertised difficulty.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I feel the quality of the course is poor because the difficulty is not what was promised.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy's content is not suitable for the audience it claims to target based on difficulty.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The course was labeled 'Intermediate' on Codecademy, but the content felt like it was for experts.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The content within the Codecademy course is not aligned with the stated difficulty level.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I was unprepared for the difficulty of the course content based on Codecademy's description.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The quality of the learning path is diminished because the content difficulty is wrong.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy's course content ramped up in difficulty far too quickly for a beginner course.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The material in this Codecademy course is much more complex than advertised.", "Category": "Content Quality Issue"},
    {"Complaint Text": "This 'Introductory' Codecademy course contains surprisingly advanced topics.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I'm struggling because the course content on Codecademy is harder than I was led to believe.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The learning content provided by Codecademy does not reflect the advertised difficulty.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy needs to review its course content to align it with the correct difficulty rating.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The gap between the advertised difficulty and the actual content on Codecademy is huge.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The content in this Codecademy course is not appropriate for the advertised skill level.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I am disappointed with the course quality as the content's difficulty was misrepresented.", "Category": "Content Quality Issue"},
    {"Complaint Text": "Codecademy set false expectations with its difficulty rating for this course's content.", "Category": "Content Quality Issue"},
    {"Complaint Text": "This Codecademy course's content is definitely not for beginners as claimed.", "Category": "Content Quality Issue"},
]

# %%
complaints_data += [
    # Complaint 66 – Misleading Course Description
    {"Complaint Text": "The topics covered in the Codecademy course were different from the syllabus.", "Category": "Misleading Course Description"},
    {"Complaint Text": "What was taught in the Codecademy course was not what was described on the sales page.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course description for this Codecademy class was highly inaccurate.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I enrolled based on a course description that did not reflect the actual content on Codecademy.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's course description was misleading; many promised topics were not covered.", "Category": "Misleading Course Description"},
    {"Complaint Text": "There was a significant discrepancy between the Codecademy course description and its content.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course I took on Codecademy did not match the outline provided beforehand.", "Category": "Misleading Course Description"},
    {"Complaint Text": "This feels like a bait-and-switch; the Codecademy course content is not what I signed up for.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course on Codecademy failed to deliver on the content promised in its description.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's description mentioned several key technologies that were never even mentioned in the course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The learning path I followed on Codecademy diverged significantly from its description.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I am requesting a refund because the Codecademy course content was not as described.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The marketing material for the Codecademy course was deceptive regarding the content.", "Category": "Misleading Course Description"},
    {"Complaint Text": "This course on Codecademy had a completely different focus than what the description implied.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Key modules listed in the Codecademy course description were missing from the actual course.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I feel cheated because the Codecademy course content did not align with its public description.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The curriculum taught in the Codecademy course was not the one that was advertised.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's course description set false expectations about the topics to be covered.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The information in the Codecademy course description was false and misleading.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The final project was on a topic completely unrelated to the Codecademy course description.", "Category": "Misleading Course Description"},
]

# %%
complaints_data += [
    # Complaint 67 – Payment Issue
    {"Complaint Text": "My payment on Codecademy failed, but I was still charged and not refunded.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy charged me for a failed transaction and has not returned the money.", "Category": "Payment Issue"},
    {"Complaint Text": "I received a payment error on Codecademy, but the charge appeared on my card and wasn't refunded.", "Category": "Payment Issue"},
    {"Complaint Text": "A failed payment attempt on Codecademy resulted in a charge that I have not been refunded for.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy needs to refund me for a transaction that failed on their end.", "Category": "Payment Issue"},
    {"Complaint Text": "The website said my payment failed, but my bank says Codecademy took the money and won't refund it.", "Category": "Payment Issue"},
    {"Complaint Text": "I'm still waiting for a refund from Codecademy for a payment that didn't go through correctly.", "Category": "Payment Issue"},
    {"Complaint Text": "My money is stuck with Codecademy after a failed payment, and no refund has been issued.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy has not processed the refund for a charge associated with a failed transaction.", "Category": "Payment Issue"},
    {"Complaint Text": "I was incorrectly charged by Codecademy during a payment failure and the refund is missing.", "Category": "Payment Issue"},
    {"Complaint Text": "My subscription was not activated due to payment failure, but Codecademy kept the money.", "Category": "Payment Issue"},
    {"Complaint Text": "I demand a refund for the amount Codecademy charged me for a payment that errored out.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy's system glitched, charged me, showed a failure, and didn't process a refund.", "Category": "Payment Issue"},
    {"Complaint Text": "How do I get my money back from Codecademy for a failed payment?", "Category": "Payment Issue"},
    {"Complaint Text": "A refund has not been initiated by Codecademy for a failed purchase attempt.", "Category": "Payment Issue"},
    {"Complaint Text": "The payment process on Codecademy failed, yet I was charged and the refund is nowhere to be seen.", "Category": "Payment Issue"},
    {"Complaint Text": "I am seeking a refund from Codecademy for an erroneous charge from a failed transaction.", "Category": "Payment Issue"},
    {"Complaint Text": "My card was charged by Codecademy despite the transaction failing, and no refund has been made.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy has not returned the funds from a payment that failed to activate my subscription.", "Category": "Payment Issue"},
    {"Complaint Text": "A failed payment on Codecademy led to a charge that has yet to be refunded.", "Category": "Payment Issue"},
]

# %%
complaints_data += [
    # Complaint 68 – Certificate Issue
    {"Complaint Text": "The certificate I received from Codecademy has the wrong course name on it.", "Category": "Certificate Issue"},
    {"Complaint Text": "My Codecademy certificate was issued with an incorrect title for the course I completed.", "Category": "Certificate Issue"},
    {"Complaint Text": "There is a typo in the course title on my official Codecademy certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy issued me a certificate for a completely different course than the one I took.", "Category": "Certificate Issue"},
    {"Complaint Text": "The course title listed on my completion certificate from Codecademy is wrong.", "Category": "Certificate Issue"},
    {"Complaint Text": "I need a corrected certificate because the one from Codecademy has an error in the title.", "Category": "Certificate Issue"},
    {"Complaint Text": "My Codecademy certificate is useless because it displays the incorrect course name.", "Category": "Certificate Issue"},
    {"Complaint Text": "The certificate I downloaded from Codecademy doesn't match the course I finished.", "Category": "Certificate Issue"},
    {"Complaint Text": "There is an error on my Codecademy certificate; the course title is inaccurate.", "Category": "Certificate Issue"},
    {"Complaint Text": "How can I get my Codecademy certificate reissued with the correct course title?", "Category": "Certificate Issue"},
    {"Complaint Text": "The professional certificate from Codecademy shows the title of a different learning path.", "Category": "Certificate Issue"},
    {"Complaint Text": "My credential from Codecademy is invalid due to an incorrect course title.", "Category": "Certificate Issue"},
    {"Complaint Text": "I completed the Python course, but my Codecademy certificate says JavaScript.", "Category": "Certificate Issue"},
    {"Complaint Text": "The automated system at Codecademy generated my certificate with the wrong course title.", "Category": "Certificate Issue"},
    {"Complaint Text": "My name is correct, but the course title on the Codecademy certificate is wrong.", "Category": "Certificate Issue"},
    {"Complaint Text": "The certificate provided by Codecademy does not accurately reflect the course I completed.", "Category": "Certificate Issue"},
    {"Complaint Text": "I'm unable to use my Codecademy certificate professionally due to the incorrect title.", "Category": "Certificate Issue"},
    {"Complaint Text": "There has been a mistake, and my Codecademy certificate has the wrong course listed.", "Category": "Certificate Issue"},
    {"Complaint Text": "The title on my certificate from Codecademy does not match my learning history.", "Category": "Certificate Issue"},
    {"Complaint Text": "I need Codecademy to fix the incorrect course title on my certificate of completion.", "Category": "Certificate Issue"},
]

# %%
complaints_data += [
    # Complaint 69 – Course Access Issue
    {"Complaint Text": "The Codecademy course I was enrolled in has disappeared without warning.", "Category": "Course Access Issue"},
    {"Complaint Text": "A course I was actively taking on Codecademy was suddenly removed.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy deleted a course from my dashboard without any prior notice.", "Category": "Course Access Issue"},
    {"Complaint Text": "I can no longer access a course I was halfway through on Codecademy; it's just gone.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy removed a course from its platform that I was still working on.", "Category": "Course Access Issue"},
    {"Complaint Text": "I was not notified that a course I was studying on Codecademy would be taken down.", "Category": "Course Access Issue"},
    {"Complaint Text": "One of my courses on Codecademy has vanished from my learning plan.", "Category": "Course Access Issue"},
    {"Complaint Text": "I lost all my progress because Codecademy removed the course without notice.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy retired a course I was in the middle of, and I received no email about it.", "Category": "Course Access Issue"},
    {"Complaint Text": "My access to a specific Codecademy course was revoked when it was removed suddenly.", "Category": "Course Access Issue"},
    {"Complaint Text": "Why was a course I was enrolled in removed from Codecademy without a heads-up?", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy needs to inform users before they remove courses from the platform.", "Category": "Course Access Issue"},
    {"Complaint Text": "I can't find a course I was taking on Codecademy anymore; it seems to have been deleted.", "Category": "Course Access Issue"},
    {"Complaint Text": "It's unfair that Codecademy removed a course I was learning from without any notification.", "Category": "Course Access Issue"},
    {"Complaint Text": "The course I was studying on Codecademy is no longer available, and I was not warned.", "Category": "Course Access Issue"},
    {"Complaint Text": "My learning path on Codecademy is now broken because a core course was removed.", "Category": "Course Access Issue"},
    {"Complaint Text": "I had lifetime access to a Codecademy course that has now been removed.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy took down a course without providing an alternative or a notification.", "Category": "Course Access Issue"},
    {"Complaint Text": "I went to continue my lesson, and the entire course was gone from Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Access to a course I was studying on Codecademy was terminated abruptly.", "Category": "Course Access Issue"},
]

# %%
complaints_data += [
    # Complaint 70 – Instructor Issue
    {"Complaint Text": "The feedback I received from the instructor in the Codecademy forums was vague and unhelpful.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor's responses in the Codecademy discussion boards did not answer my question.", "Category": "Instructor Issue"},
    {"Complaint Text": "I asked for help, and the Codecademy instructor's feedback was not constructive at all.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor on Codecademy provided feedback that was confusing and didn't help me solve the problem.", "Category": "Instructor Issue"},
    {"Complaint Text": "The quality of instructor feedback in the Codecademy forums is very poor.", "Category": "Instructor Issue"},
    {"Complaint Text": "I found the instructor's feedback on my project submission to be completely useless.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor on Codecademy seems to give generic, unhelpful replies in the forums.", "Category": "Instructor Issue"},
    {"Complaint Text": "I am still stuck because the feedback from the Codecademy instructor was not clear.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor's comments in the Q&A section of Codecademy were not helpful for my issue.", "Category": "Instructor Issue"},
    {"Complaint Text": "I was disappointed with the shallow and unhelpful feedback from the course instructor on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor's advice in the Codecademy forums didn't guide me to the right solution.", "Category": "Instructor Issue"},
    {"Complaint Text": "For the price I paid, I expected much more helpful instructor feedback on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "The official instructor feedback on Codecademy was less helpful than that from other students.", "Category": "Instructor Issue"},
    {"Complaint Text": "I received dismissive and unhelpful feedback from the instructor on the Codecademy platform.", "Category": "Instructor Issue"},
    {"Complaint Text": "The support from the instructor in the Codecademy forums was inadequate and unhelpful.", "Category": "Instructor Issue"},
    {"Complaint Text": "The feedback loop with the instructor on Codecademy is broken because their advice is not helpful.", "Category": "Instructor Issue"},
    {"Complaint Text": "I feel the instructor on Codecademy didn't properly read my question before giving unhelpful feedback.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor's replies in the community forum on Codecademy lacked any real substance or help.", "Category": "Instructor Issue"},
    {"Complaint Text": "My progress is stalled due to the unhelpful nature of the instructor's feedback on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "The feedback provided by the assigned instructor on Codecademy did not help my learning.", "Category": "Instructor Issue"},
]

# %%
complaints_data += [
    # Complaint 71 – Technical Glitch (Syncing)
    {"Complaint Text": "My course progress on the Codecademy mobile app is not syncing with the website version.", "Category": "Technical Glitch"},
    {"Complaint Text": "The progress I make on my phone in the Codecademy app doesn't show up on my laptop.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy fails to correctly sync my learning progress between my tablet and my desktop.", "Category": "Technical Glitch"},
    {"Complaint Text": "There is no cross-device synchronization for my course progress on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "When I switch devices, my lesson progress on Codecademy is lost or outdated.", "Category": "Technical Glitch"},
    {"Complaint Text": "The Codecademy app and the website are not in sync with each other regarding my progress.", "Category": "Technical Glitch"},
    {"Complaint Text": "I completed a lesson on the app, but the Codecademy website still shows it as incomplete.", "Category": "Technical Glitch"},
    {"Complaint Text": "Progress synchronization is clearly broken between different devices on the Codecademy platform.", "Category": "Technical Glitch"},
    {"Complaint Text": "My Codecademy account does not have a unified progress tracker that works across platforms.", "Category": "Technical Glitch"},
    {"Complaint Text": "The work I do on the Codecademy iOS app is not being reflected on the web version.", "Category": "Technical Glitch"},
    {"Complaint Text": "I am forced to redo lessons when I change devices because Codecademy doesn't sync properly.", "Category": "Technical Glitch"},
    {"Complaint Text": "The cloud sync feature for my Codecademy progress is malfunctioning.", "Category": "Technical Glitch"},
    {"Complaint Text": "There's a persistent technical glitch that is preventing my Codecademy progress from syncing.", "Category": "Technical Glitch"},
    {"Complaint Text": "The Android app for Codecademy isn't syncing my completed lessons to my main account.", "Category": "Technical Glitch"},
    {"Complaint Text": "My learning path on Codecademy shows different completion percentages on my phone versus my computer.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy's multi-device support is failing because it doesn't sync my course progress.", "Category": "Technical Glitch"},
    {"Complaint Text": "I expect my Codecademy progress to be the same everywhere, but it's not syncing correctly.", "Category": "Technical Glitch"},
    {"Complaint Text": "The lack of reliable progress sync between the Codecademy app and website is very frustrating.", "Category": "Technical Glitch"},
    {"Complaint Text": "My account on Codecademy does not update my progress when I switch from mobile to web.", "Category": "Technical Glitch"},
    {"Complaint Text": "I am having major issues with inconsistent progress tracking across my devices on Codecademy.", "Category": "Technical Glitch"},
]

# %%
complaints_data += [
    # Complaint 72 – Certificate Issue
    {"Complaint Text": "I finished a Codecademy course 100%, but no certificate was generated.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy failed to issue my certificate after I completed all the course requirements.", "Category": "Certificate Issue"},
    {"Complaint Text": "My course is marked as complete on Codecademy, but I have not received my certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "I am unable to claim my certificate even though I have finished the Codecademy course.", "Category": "Certificate Issue"},
    {"Complaint Text": "The system at Codecademy has not issued the certificate I earned.", "Category": "Certificate Issue"},
    {"Complaint Text": "After finishing my learning path on Codecademy, the certificate was not awarded.", "Category": "Certificate Issue"},
    {"Complaint Text": "I have completed the final project, but my Codecademy certificate has not been issued.", "Category": "Certificate Issue"},
    {"Complaint Text": "There is no option to download my certificate on Codecademy after course completion.", "Category": "Certificate Issue"},
    {"Complaint Text": "I'm still waiting for Codecademy to issue my certificate days after I finished the course.", "Category": "Certificate Issue"},
    {"Complaint Text": "My Codecademy dashboard shows 100% completion, but the certificate is missing.", "Category": "Certificate Issue"},
    {"Complaint Text": "Despite completing the course, a certificate was not made available to me on Codecademy.", "Category": "Certificate Issue"},
    {"Complaint Text": "How do I get my certificate? Codecademy didn't issue one automatically.", "Category": "Certificate Issue"},
    {"Complaint Text": "The certificate of completion for my Codecademy course was never delivered.", "Category": "Certificate Issue"},
    {"Complaint Text": "I'm having trouble getting my certificate from Codecademy after finishing a course.", "Category": "Certificate Issue"},
    {"Complaint Text": "The final step of my Codecademy course, issuing the certificate, has failed.", "Category": "Certificate Issue"},
    {"Complaint Text": "I've fulfilled all the criteria, but Codecademy has not provided my certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "My profile on Codecademy is not showing the certificate I should have received.", "Category": "Certificate Issue"},
    {"Complaint Text": "I need proof of completion, but Codecademy hasn't issued my certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "There seems to be a delay or error in issuing my certificate from Codecademy.", "Category": "Certificate Issue"},
    {"Complaint Text": "My course completion on Codecademy did not trigger the issuance of a certificate.", "Category": "Certificate Issue"},
]

# %%
complaints_data += [
    # Complaint 73 – Misleading Course Description
    {"Complaint Text": "I lost access to a Codecademy course that was advertised as having 'lifetime access'.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The 'lifetime access' promise for my Codecademy course was false.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy revoked my access to a course that I was told I would have forever.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I purchased a Codecademy course because it offered lifetime access, but now it's gone.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course description on Codecademy was misleading about the duration of access.", "Category": "Misleading Course Description"},
    {"Complaint Text": "My lifetime access to a Codecademy course has been terminated without explanation.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's claim of 'buy once, own forever' for this course was not honored.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I can no longer get into a Codecademy course that was sold with lifetime access.", "Category": "Misleading Course Description"},
    {"Complaint Text": "This is false advertising; the Codecademy course does not have lifetime access as stated.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I paid for permanent access to a Codecademy course, and now it's unavailable to me.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy's definition of 'lifetime access' seems to be different from everyone else's.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I feel deceived by Codecademy's misleading 'lifetime access' offer.", "Category": "Misleading Course Description"},
    {"Complaint Text": "My access to a previously purchased Codecademy course has expired, despite it being a 'lifetime' purchase.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The sales page for the Codecademy course clearly stated 'lifetime access', which I no longer have.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy removed a course for which I had paid for lifetime access.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I am complaining because the promised lifetime access on my Codecademy course was not provided.", "Category": "Misleading Course Description"},
    {"Complaint Text": "The course on Codecademy was not a lifetime purchase as was advertised.", "Category": "Misleading Course Description"},
    {"Complaint Text": "My perpetual access to a Codecademy course has been unjustly revoked.", "Category": "Misleading Course Description"},
    {"Complaint Text": "Codecademy went back on their word regarding lifetime access to this course material.", "Category": "Misleading Course Description"},
    {"Complaint Text": "I'm locked out of a course on Codecademy that was supposed to be mine forever.", "Category": "Misleading Course Description"},
]

# %%
complaints_data += [
    # Complaint 74 – Instructor Issue
    {"Complaint Text": "The Codecademy instructor kept canceling the scheduled live support sessions.", "Category": "Instructor Issue"},
    {"Complaint Text": "Most of the live sessions with our instructor on Codecademy were cancelled at the last minute.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor for my Codecademy course was unreliable and frequently cancelled live help sessions.", "Category": "Instructor Issue"},
    {"Complaint Text": "I couldn't get the help I needed because the Codecademy instructor's live sessions were always being cancelled.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor failed to show up for many of the promised live support events on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "There were constant cancellations of the live support office hours with the Codecademy instructor.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor's frequent cancellation of live sessions on Codecademy was very unprofessional.", "Category": "Instructor Issue"},
    {"Complaint Text": "We were promised weekly live support from the instructor, but most sessions on Codecademy were cancelled.", "Category": "Instructor Issue"},
    {"Complaint Text": "It was difficult to learn when the live support sessions on Codecademy were so often cancelled by the instructor.", "Category": "Instructor Issue"},
    {"Complaint Text": "My course experience was poor due to the instructor repeatedly cancelling live sessions on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "The live Q&A sessions on Codecademy with the instructor were more often cancelled than held.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor for this Codecademy course has a habit of cancelling the live support meetings.", "Category": "Instructor Issue"},
    {"Complaint Text": "I am frustrated by the number of times the instructor has cancelled live sessions on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "The reliability of the instructor was poor; live help sessions on Codecademy were always at risk of cancellation.", "Category": "Instructor Issue"},
    {"Complaint Text": "I cleared my schedule for live support sessions on Codecademy only for the instructor to cancel them.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor provided very little live support as most scheduled sessions on Codecademy were cancelled.", "Category": "Instructor Issue"},
    {"Complaint Text": "We received numerous 'session cancelled' notifications from our Codecademy instructor.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor's commitment to live sessions on Codecademy was lacking, as evidenced by frequent cancellations.", "Category": "Instructor Issue"},
    {"Complaint Text": "It's hard to get questions answered when the Codecademy instructor keeps cancelling the live support.", "Category": "Instructor Issue"},
    {"Complaint Text": "The promised instructor-led live sessions on Codecademy were frequently and consistently cancelled.", "Category": "Instructor Issue"},
]

# %%
complaints_data += [
    # Complaint 75 – Technical Glitch (Content Loading)
    {"Complaint Text": "I am unable to get the lesson videos on the Codecademy platform to play.", "Category": "Technical Glitch"},
    {"Complaint Text": "The actual course content on Codecademy is stuck on an infinite loading screen.", "Category": "Technical Glitch"},
    {"Complaint Text": "None of the videos or interactive lessons are loading for me on the Codecademy platform.", "Category": "Technical Glitch"},
    {"Complaint Text": "I am unable to proceed with my course because the next lesson on Codecademy will not load.", "Category": "Technical Glitch"},
    {"Complaint Text": "There is a persistent technical issue preventing videos from loading in my Codecademy course.", "Category": "Technical Glitch"},
    {"Complaint Text": "The lesson pages on the Codecademy website are blank or just show a loading spinner.", "Category": "Technical Glitch"},
    {"Complaint Text": "The embedded videos in the Codecademy lessons appear to be broken and will not play.", "Category": "Technical Glitch"},
    {"Complaint Text": "I'm experiencing constant buffering and loading issues with the Codecademy lessons.", "Category": "Technical Glitch"},
    {"Complaint Text": "The learning interface on Codecademy is failing to load the actual course material.", "Category": "Technical Glitch"},
    {"Complaint Text": "When I click on a lesson, the content and videos never appear on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "The video player for all Codecademy lessons is not working on my computer.", "Category": "Technical Glitch"},
    {"Complaint Text": "The Codecademy platform is having serious trouble loading the educational content.", "Category": "Technical Glitch"},
    {"Complaint Text": "I am getting a network error message when I try to load any lesson on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "My learning has stalled because the lessons themselves will not load on the Codecademy platform.", "Category": "Technical Glitch"},
    {"Complaint Text": "Both the video content and text-based lessons are failing to load correctly on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "The course module content is completely inaccessible due to a loading glitch on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "I have tried different browsers and cleared my cache, but Codecademy lessons still will not load.", "Category": "Technical Glitch"},
    {"Complaint Text": "There is a persistent problem with lesson content not loading on the Codecademy website.", "Category": "Technical Glitch"},
    {"Complaint Text": "The interactive code editor that is part of the lessons on Codecademy is not loading.", "Category": "Technical Glitch"},
    {"Complaint Text": "I can see the course outline, but none of the actual lesson content will load on Codecademy.", "Category": "Technical Glitch"},
]

# %%
complaints_data += [
    # Complaint 76 – Refund Issue
    {"Complaint Text": "Codecademy's automated refund feature failed when I tried to use it.", "Category": "Refund Issue"},
    {"Complaint Text": "I attempted to get a refund through Codecademy's automatic system, but it's broken.", "Category": "Refund Issue"},
    {"Complaint Text": "The self-service refund option on the Codecademy website is not working correctly.", "Category": "Refund Issue"},
    {"Complaint Text": "There's a technical glitch in Codecademy's automatic refund system that prevented my refund.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund request was not processed because the automated system on Codecademy is faulty.", "Category": "Refund Issue"},
    {"Complaint Text": "The automatic refund tool on the Codecademy website returned an error message.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy's system for processing automatic refunds is clearly malfunctioning.", "Category": "Refund Issue"},
    {"Complaint Text": "I am unable to get my money back because the automated refund process on Codecademy is not functioning.", "Category": "Refund Issue"},
    {"Complaint Text": "The 'one-click refund' system promised by Codecademy failed to work.", "Category": "Refund Issue"},
    {"Complaint Text": "A system error occurred with Codecademy's automatic refund processing, and I wasn't refunded.", "Category": "Refund Issue"},
    {"Complaint Text": "The automated refund feature on the Codecademy platform did not complete my request.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy's website has a broken or non-functional automatic refund system.", "Category": "Refund Issue"},
    {"Complaint Text": "I followed all the steps for an automatic refund on Codecademy, but it didn't go through.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund system on Codecademy is supposed to be automatic, but it failed for my account.", "Category": "Refund Issue"},
    {"Complaint Text": "There seems to be a significant bug with the automated refund functionality on Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "My attempt to use the self-service refund on Codecademy was unsuccessful due to a system fault.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy's automatic refund workflow is not operational and needs to be fixed.", "Category": "Refund Issue"},
    {"Complaint Text": "The instant refund system on the Codecademy site is not working as advertised.", "Category": "Refund Issue"},
    {"Complaint Text": "I encountered a system error when trying to use the automatic refund feature on Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "The automatic refund process on the Codecademy website timed out and failed.", "Category": "Refund Issue"},
]

# %%
complaints_data += [
    # Complaint 77 – Course Access Issue
    {"Complaint Text": "I can't access the next module in my Codecademy course although it's scheduled to be unlocked.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy is not unlocking new course modules on the correct dates as per the syllabus.", "Category": "Course Access Issue"},
    {"Complaint Text": "The scheduled content release for my drip-feed Codecademy course is delayed.", "Category": "Course Access Issue"},
    {"Complaint Text": "I'm stuck in my learning path because the next module on Codecademy hasn't unlocked on time.", "Category": "Course Access Issue"},
    {"Complaint Text": "The drip content feature for my course on Codecademy is not working correctly.", "Category": "Course Access Issue"},
    {"Complaint Text": "New lessons on Codecademy are not becoming available according to the official course schedule.", "Category": "Course Access Issue"},
    {"Complaint Text": "My course progression is halted because Codecademy modules are not unlocking as scheduled.", "Category": "Course Access Issue"},
    {"Complaint Text": "The weekly modules for my Codecademy career path are not being released on schedule.", "Category": "Course Access Issue"},
    {"Complaint Text": "I have to wait well past the release date for new modules to unlock on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "There's a problem with module access; they are not unlocking as promised on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "The timed release of my course content on the Codecademy platform is failing.", "Category": "Course Access Issue"},
    {"Complaint Text": "I should have access to the next chapter of my course, but it's still locked on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy's system is failing to unlock course modules according to the syllabus timeline.", "Category": "Course Access Issue"},
    {"Complaint Text": "The content unlocking mechanism for my timed course on Codecademy is delayed.", "Category": "Course Access Issue"},
    {"Complaint Text": "I'm falling behind schedule because new modules aren't accessible on the specified dates on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Access to new course sections on Codecademy is not being granted according to the schedule.", "Category": "Course Access Issue"},
    {"Complaint Text": "The next part of my course is still locked, even though it's past the official release time on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "I'm having issues with the timed content access on my Codecademy professional certificate course.", "Category": "Course Access Issue"},
    {"Complaint Text": "The course schedule on Codecademy indicates the module should be open, but it is not.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy is not adhering to its own content release schedule for my course.", "Category": "Course Access Issue"},
]

# %%
complaints_data += [
    # Complaint 78 – Certificate Issue
    {"Complaint Text": "My Codecademy certificate has details that are inconsistent with the course I actually completed.", "Category": "Certificate Issue"},
    {"Complaint Text": "There's a major discrepancy between my Codecademy certificate's information and the course I took.", "Category": "Certificate Issue"},
    {"Complaint Text": "The course details listed on my Codecademy certificate are completely inaccurate.", "Category": "Certificate Issue"},
    {"Complaint Text": "The certificate I got from Codecademy lists the wrong completion date and course code.", "Category": "Certificate Issue"},
    {"Complaint Text": "My Codecademy certificate has the wrong course title and a mismatched description.", "Category": "Certificate Issue"},
    {"Complaint Text": "The information on my Codecademy certificate is inconsistent with my personal learning record.", "Category": "Certificate Issue"},
    {"Complaint Text": "I need a new certificate because the course details on my current one from Codecademy are wrong.", "Category": "Certificate Issue"},
    {"Complaint Text": "The course specifics mentioned on my Codecademy certificate do not align with the actual course content.", "Category": "Certificate Issue"},
    {"Complaint Text": "The certificate issued by Codecademy does not correctly represent the course I finished.", "Category": "Certificate Issue"},
    {"Complaint Text": "There are multiple errors in the course details section of my Codecademy certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "My certificate from Codecademy has the wrong hours and course code listed on it.", "Category": "Certificate Issue"},
    {"Complaint Text": "The content of my Codecademy certificate does not match the specific details of the completed course.", "Category": "Certificate Issue"},
    {"Complaint Text": "The certificate I received from Codecademy seems to be a template for a different course.", "Category": "Certificate Issue"},
    {"Complaint Text": "The details on my Codecademy certificate, such as the duration and title, are incorrect.", "Category": "Certificate Issue"},
    {"Complaint Text": "My Codecademy certificate is invalid because it misrepresents the details of the course I took.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy's system generated a certificate for me with conflicting course information.", "Category": "Certificate Issue"},
    {"Complaint Text": "The certificate I earned from Codecademy does not accurately reflect the course particulars.", "Category": "Certificate Issue"},
    {"Complaint Text": "The course summary printed on my Codecademy certificate is completely wrong.", "Category": "Certificate Issue"},
    {"Complaint Text": "I need Codecademy to urgently correct the multiple course detail errors on my certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "My professional credential from Codecademy is flawed because of the mismatched course details.", "Category": "Certificate Issue"},
]

# %%
complaints_data += [
    # Complaint 79 – Content Quality Issue
    {"Complaint Text": "The content in my Codecademy course is extremely repetitive and doesn't go into any real depth.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I'm very disappointed with the shallow and repetitive material in this Codecademy course.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The course on Codecademy is far too basic for its title and keeps repeating the same simple concepts.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The content quality is poor; the material is overly simplified and highly redundant on Codecademy.", "Category": "Content Quality Issue"},
    {"Complaint Text": "This Codecademy course is not challenging in the slightest; the content is just repeated constantly.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I feel like I'm not learning anything new because the Codecademy course content is so repetitive.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The curriculum on Codecademy is filled with overly simplified and repeated information.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The learning material in this Codecademy course lacks substance and is very repetitive.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The course content on Codecademy is not well-structured and repeats itself constantly, which is frustrating.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I expected more advanced topics, but this Codecademy course is just repetitive and very basic.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The educational value of this particular Codecademy course is low due to its highly repetitive nature.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The lessons on Codecademy cover the same simple points over and over again without building on them.", "Category": "Content Quality Issue"},
    {"Complaint Text": "There is a lot of filler content in this Codecademy course that is just pointless repetition.", "Category": "Content Quality Issue"},
    {"Complaint Text": "This course on Codecademy is not worth the money because the content is too simplified and repetitive.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The quality of the material is poor; this Codecademy course is repetitive and lacks any significant depth.", "Category": "Content Quality Issue"},
    {"Complaint Text": "I'm frustrated with how the Codecademy course continually rehashes the same simple ideas.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The content on Codecademy for this course could be condensed by half; it's too repetitive.", "Category": "Content Quality Issue"},
    {"Complaint Text": "This course felt like a waste of my time due to the overly simplified and repeated content on Codecademy.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The Codecademy course material is not engaging because it's so repetitive and simplistic.", "Category": "Content Quality Issue"},
    {"Complaint Text": "The depth of this course on Codecademy is minimal, with many repetitive and uninspired exercises.", "Category": "Content Quality Issue"},
]

# %%
complaints_data += [
    # Complaint 80 – Refund Issue
    {"Complaint Text": "Codecademy sent my refund to a different card than the one I used for payment.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund from Codecademy was issued to the wrong payment source.", "Category": "Refund Issue"},
    {"Complaint Text": "I requested a refund to my PayPal, but Codecademy sent it to an old credit card.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund from Codecademy was not returned to my original payment method.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy processed my refund incorrectly, sending it to the wrong account.", "Category": "Refund Issue"},
    {"Complaint Text": "I can't access my refund because Codecademy sent it to a closed bank account.", "Category": "Refund Issue"},
    {"Complaint Text": "There was an error in my refund processing; Codecademy used the wrong payment method.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund from Codecademy went to an expired credit card.", "Category": "Refund Issue"},
    {"Complaint Text": "I need Codecademy to reissue my refund to the correct payment method.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy support confirmed the refund, but it was sent to the wrong place.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund was misdirected by Codecademy to a payment method I no longer use.", "Category": "Refund Issue"},
    {"Complaint Text": "The payment method used for my Codecademy refund was not the one I paid with.", "Category": "Refund Issue"},
    {"Complaint Text": "I am having trouble locating my refund because Codecademy processed it to an incorrect destination.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy made a mistake and did not refund the money to my original payment method.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund is lost because Codecademy sent it to the wrong card.", "Category": "Refund Issue"},
    {"Complaint Text": "The financial transaction for my refund from Codecademy was handled incorrectly.", "Category": "Refund Issue"},
    {"Complaint Text": "I have not received my money because Codecademy refunded it to the wrong payment method.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy's refund process is flawed; it sent my money to the wrong account.", "Category": "Refund Issue"},
    {"Complaint Text": "I specifically requested the refund to my current card, but Codecademy ignored it.", "Category": "Refund Issue"},
    {"Complaint Text": "An error by Codecademy resulted in my refund being sent to an invalid payment method.", "Category": "Refund Issue"},
]

# %%
complaints_data += [
    # Complaint 81 – Instructor Issue
    {"Complaint Text": "The reference links provided by the Codecademy instructor are all broken.", "Category": "Instructor Issue"},
    {"Complaint Text": "Many of the external resources linked by the Codecademy instructor lead to 404 errors.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor for my Codecademy course shared a list of references with dead links.", "Category": "Instructor Issue"},
    {"Complaint Text": "I can't access the supplementary materials because the instructor on Codecademy provided broken URLs.", "Category": "Instructor Issue"},
    {"Complaint Text": "The quality of instruction is poor when the Codecademy instructor provides non-working reference links.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor's resource list for my Codecademy course is useless because the links are broken.", "Category": "Instructor Issue"},
    {"Complaint Text": "None of the reference links from the Codecademy instructor are functional.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor needs to update the course materials; the reference links on Codecademy are all dead.", "Category": "Instructor Issue"},
    {"Complaint Text": "I'm frustrated because the Codecademy instructor's recommended links do not work.", "Category": "Instructor Issue"},
    {"Complaint Text": "The further reading section from the Codecademy instructor is full of broken hyperlinks.", "Category": "Instructor Issue"},
    {"Complaint Text": "I received no value from the references as the links from the Codecademy instructor were broken.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor showed a lack of diligence by providing outdated and broken links on Codecademy.", "Category": "Instructor Issue"},
    {"Complaint Text": "My learning is hindered because the Codecademy instructor's resource links are all invalid.", "Category": "Instructor Issue"},
    {"Complaint Text": "Every reference link I've tried from the Codecademy instructor has led to an error page.", "Category": "Instructor Issue"},
    {"Complaint Text": "The instructor for my Codecademy course needs to quality-check their links; they are all broken.", "Category": "Instructor Issue"},
    {"Complaint Text": "The links shared by the instructor in the Codecademy forums are not working.", "Category": "Instructor Issue"},
    {"Complaint Text": "It is unprofessional for a Codecademy instructor to provide so many broken reference links.", "Category": "Instructor Issue"},
    {"Complaint Text": "I'm trying to study more, but the Codecademy instructor's links are all defunct.", "Category": "Instructor Issue"},
    {"Complaint Text": "The external documentation links provided by the instructor on Codecademy are broken.", "Category": "Instructor Issue"},
    {"Complaint Text": "The supplementary links from the Codecademy instructor are not maintained and are all broken.", "Category": "Instructor Issue"},
]

# %%
complaints_data += [
    # Complaint 82 – Technical Glitch
    {"Complaint Text": "The Codecademy website consistently crashes whenever I'm doing a coding exercise.", "Category": "Technical Glitch"},
    {"Complaint Text": "My web browser freezes and then crashes when I am working on Codecademy's coding exercises.", "Category": "Technical Glitch"},
    {"Complaint Text": "The Codecademy platform is unstable and frequently crashes during the hands-on coding parts of lessons.", "Category": "Technical Glitch"},
    {"Complaint Text": "I am unable to complete my lessons because the Codecademy platform crashes when I'm writing code.", "Category": "Technical Glitch"},
    {"Complaint Text": "The interactive coding environment on Codecademy is causing my entire system to crash.", "Category": "Technical Glitch"},
    {"Complaint Text": "There's a major bug on Codecademy that makes the platform crash during practical exercises.", "Category": "Technical Glitch"},
    {"Complaint Text": "I keep losing all my progress in an exercise when the Codecademy site suddenly crashes.", "Category": "Technical Glitch"},
    {"Complaint Text": "The coding sandbox on the Codecademy platform is very buggy and often crashes the whole page.", "Category": "Technical Glitch"},
    {"Complaint Text": "My learning session on Codecademy terminates unexpectedly whenever I start a coding exercise.", "Category": "Technical Glitch"},
    {"Complaint Text": "The platform is unusable for coding exercises because it crashes so frequently.", "Category": "Technical Glitch"},
    {"Complaint Text": "Running my code in the Codecademy editor causes the entire browser tab to become unresponsive and crash.", "Category": "Technical Glitch"},
    {"Complaint Text": "I am experiencing repeated crashes on the Codecademy platform, specifically during the coding tasks.", "Category": "Technical Glitch"},
    {"Complaint Text": "The technical stability of the Codecademy platform is very poor; it crashes while I'm trying to code.", "Category": "Technical Glitch"},
    {"Complaint Text": "I'm unable to practice coding effectively on Codecademy because the platform keeps crashing.", "Category": "Technical Glitch"},
    {"Complaint Text": "The coding interface on Codecademy seems to have a memory leak, which causes it to crash.", "Category": "Technical Glitch"},
    {"Complaint Text": "Every time I try to submit code in an exercise, the Codecademy platform crashes.", "Category": "Technical Glitch"},
    {"Complaint Text": "The website becomes unresponsive and then crashes in the middle of coding exercises on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "There is a critical technical glitch causing the Codecademy platform to crash during code execution.", "Category": "Technical Glitch"},
    {"Complaint Text": "I've tried using different browsers, but Codecademy still crashes when I do the coding exercises.", "Category": "Technical Glitch"},
    {"Complaint Text": "The hands-on learning experience on Codecademy is ruined by these constant platform crashes.", "Category": "Technical Glitch"},
]

# %%
complaints_data += [
    # Complaint 83 – Refund Issue
    {"Complaint Text": "I cancelled my Codecademy subscription but my refund has still not been processed.", "Category": "Refund Issue"},
    {"Complaint Text": "After cancelling my plan on Codecademy, I never received the promised refund.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund request following my Codecademy subscription cancellation has been ignored.", "Category": "Refund Issue"},
    {"Complaint Text": "It's been weeks since I cancelled my Codecademy subscription, and I'm still waiting for my refund.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy has failed to process my refund after I cancelled my subscription within the refund period.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund associated with my subscription cancellation on Codecademy has not been initiated.", "Category": "Refund Issue"},
    {"Complaint Text": "I properly cancelled my Codecademy subscription but have yet to see a refund.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy acknowledged my cancellation but has not processed the refund.", "Category": "Refund Issue"},
    {"Complaint Text": "I am still waiting for my money back from Codecademy after cancelling my subscription.", "Category": "Refund Issue"},
    {"Complaint Text": "My request for a refund upon cancellation on Codecademy has not been actioned.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund process seems to be stuck after I cancelled my Codecademy plan.", "Category": "Refund Issue"},
    {"Complaint Text": "I cancelled my subscription well within the refund window, but Codecademy hasn't refunded me.", "Category": "Refund Issue"},
    {"Complaint Text": "Where is my refund? I cancelled my Codecademy subscription ages ago.", "Category": "Refund Issue"},
    {"Complaint Text": "Despite cancelling my Codecademy subscription, the refund has not been forthcoming.", "Category": "Refund Issue"},
    {"Complaint Text": "The financial part of my cancellation with Codecademy—the refund—has not been completed.", "Category": "Refund Issue"},
    {"Complaint Text": "I need help getting my refund processed after a successful subscription cancellation on Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy's support is not responding to my queries about my missing refund post-cancellation.", "Category": "Refund Issue"},
    {"Complaint Text": "I have proof of cancellation, but no proof of a refund from Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "The final step of my cancellation, the refund, has not been handled by Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "I am owed a refund from Codecademy that was not processed when I cancelled my plan.", "Category": "Refund Issue"},
]

# %%
complaints_data += [
    # Complaint 84 – Technical Glitch
    {"Complaint Text": "My progress percentage on Codecademy is stuck and not updating.", "Category": "Technical Glitch"},
    {"Complaint Text": "The progress tracking feature on Codecademy is showing incorrect information.", "Category": "Technical Glitch"},
    {"Complaint Text": "Completed lessons on Codecademy are not being reflected in my overall progress.", "Category": "Technical Glitch"},
    {"Complaint Text": "There's a technical glitch with the progress bar on my Codecademy courses.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy's system is failing to update my course progress accurately.", "Category": "Technical Glitch"},
    {"Complaint Text": "My learning path on Codecademy shows a lower completion rate than what I've actually done.", "Category": "Technical Glitch"},
    {"Complaint Text": "The progress tracking on Codecademy is not working, it's not saving my advancements.", "Category": "Technical Glitch"},
    {"Complaint Text": "I'm having to manually track my progress because Codecademy's system is broken.", "Category": "Technical Glitch"},
    {"Complaint Text": "The dashboard on Codecademy is not updating to show my latest completed modules.", "Category": "Technical Glitch"},
    {"Complaint Text": "There is a significant lag or failure in how Codecademy updates progress tracking.", "Category": "Technical Glitch"},
    {"Complaint Text": "My course progress on Codecademy is not being correctly recorded.", "Category": "Technical Glitch"},
    {"Complaint Text": "I've finished several units, but my progress tracker on Codecademy hasn't moved.", "Category": "Technical Glitch"},
    {"Complaint Text": "The progress monitoring tool on the Codecademy platform is malfunctioning.", "Category": "Technical Glitch"},
    {"Complaint Text": "I'm experiencing issues with the progress tracking feature not updating on Codecademy.", "Category": "Technical Glitch"},
    {"Complaint Text": "Codecademy's progress tracking is unreliable and not updating in real-time.", "Category": "Technical Glitch"},
    {"Complaint Text": "The checkmarks and progress bar on Codecademy are not updating correctly after I complete lessons.", "Category": "Technical Glitch"},
    {"Complaint Text": "A bug in Codecademy's platform is preventing my progress from being tracked correctly.", "Category": "Technical Glitch"},
    {"Complaint Text": "My true progress is not being displayed on my Codecademy learning dashboard.", "Category": "Technical Glitch"},
    {"Complaint Text": "The system on Codecademy isn't registering my completed exercises in the progress tracker.", "Category": "Technical Glitch"},
    {"Complaint Text": "I am concerned that my progress on Codecademy is being lost due to a tracking glitch.", "Category": "Technical Glitch"},
]

# %%
complaints_data += [
    # Complaint 85 – Refund Issue
    {"Complaint Text": "My Codecademy account still says 'Refund Pending' even though it's been weeks.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund status on my Codecademy profile has not been updated at all.", "Category": "Refund Issue"},
    {"Complaint Text": "I have no idea what's happening with my refund because the status isn't updated on Codecademy.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy's system is not updating the status of my refund request.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund status in my Codecademy account dashboard is stuck and not changing.", "Category": "Refund Issue"},
    {"Complaint Text": "I received my refund, but my Codecademy account still shows it as processing.", "Category": "Refund Issue"},
    {"Complaint Text": "There is no update on my refund status within my Codecademy account settings.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund tracker on the Codecademy website is not providing any new information.", "Category": "Refund Issue"},
    {"Complaint Text": "My Codecademy account's refund section is not reflecting the actual status of my money.", "Category": "Refund Issue"},
    {"Complaint Text": "I am in the dark about my refund because the status on Codecademy is not updated.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy has failed to update the refund status on my account page.", "Category": "Refund Issue"},
    {"Complaint Text": "The lack of updates on my refund status in my Codecademy account is concerning.", "Category": "Refund Issue"},
    {"Complaint Text": "I need Codecademy to update the refund status on my account so I know what's happening.", "Category": "Refund Issue"},
    {"Complaint Text": "The information about my refund status on my Codecademy account is outdated.", "Category": "Refund Issue"},
    {"Complaint Text": "My refund has been processed by my bank, but Codecademy's account status says otherwise.", "Category": "Refund Issue"},
    {"Complaint Text": "There is a delay or error in updating the refund status in the Codecademy system.", "Category": "Refund Issue"},
    {"Complaint Text": "The refund status on my Codecademy account is not being refreshed.", "Category": "Refund Issue"},
    {"Complaint Text": "I'm getting conflicting information because my Codecademy account's refund status is wrong.", "Category": "Refund Issue"},
    {"Complaint Text": "Codecademy's platform is not showing the correct, up-to-date status of my refund.", "Category": "Refund Issue"},
    {"Complaint Text": "The user-facing refund status in my Codecademy account is not being updated.", "Category": "Refund Issue"},
]

# %%
complaints_data += [
    # Complaint 86 – Payment Issue
    {"Complaint Text": "Codecademy took my payment, but I still don't have access to premium features.", "Category": "Payment Issue"},
    {"Complaint Text": "My card was charged by Codecademy, but the Pro features were not unlocked on my account.", "Category": "Payment Issue"},
    {"Complaint Text": "I paid for premium, but Codecademy has not granted me access to the features.", "Category": "Payment Issue"},
    {"Complaint Text": "The money was deducted for a Pro subscription, but Codecademy hasn't unlocked the premium content.", "Category": "Payment Issue"},
    {"Complaint Text": "My payment to Codecademy was successful, but the premium benefits are still locked.", "Category": "Payment Issue"},
    {"Complaint Text": "I am unable to access premium features on Codecademy even after my payment was processed.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy charged me for Pro, but my account still behaves like a free account.", "Category": "Payment Issue"},
    {"Complaint Text": "The premium features I paid for on Codecademy have not been activated.", "Category": "Payment Issue"},
    {"Complaint Text": "My payment was deducted, yet the premium access on Codecademy remains blocked.", "Category": "Payment Issue"},
    {"Complaint Text": "There was an error where Codecademy took my money but didn't unlock premium access.", "Category": "Payment Issue"},
    {"Complaint Text": "I have a receipt from Codecademy, but none of the premium features are working.", "Category": "Payment Issue"},
    {"Complaint Text": "My account on Codecademy has not been upgraded to premium despite a successful payment.", "Category": "Payment Issue"},
    {"Complaint Text": "The premium content and features on Codecademy are still inaccessible after I paid.", "Category": "Payment Issue"},
    {"Complaint Text": "Codecademy needs to unlock the premium features for which my payment has already been deducted.", "Category": "Payment Issue"},
    {"Complaint Text": "My subscription payment was taken by Codecademy, but the premium features are not available.", "Category": "Payment Issue"},
    {"Complaint Text": "I paid for the upgrade, but Codecademy has not unlocked the premium functionalities.", "Category": "Payment Issue"},
    {"Complaint Text": "The system at Codecademy failed to unlock premium features after my payment was deducted.", "Category": "Payment Issue"},
    {"Complaint Text": "I can't access any of the Pro features on Codecademy, although my payment went through.", "Category": "Payment Issue"},
    {"Complaint Text": "My account is still restricted from premium features after Codecademy deducted the payment.", "Category": "Payment Issue"},
    {"Complaint Text": "There has been a failure to unlock the premium features on Codecademy post-payment.", "Category": "Payment Issue"},
]

# %%
complaints_data += [
    # Complaint 89 – Certificate Issue
    {"Complaint Text": "My Codecademy certificate has my name spelled incorrectly.", "Category": "Certificate Issue"},
    {"Complaint Text": "The name printed on my certificate of completion from Codecademy is wrong.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy issued my certificate with the wrong name on it.", "Category": "Certificate Issue"},
    {"Complaint Text": "There is a typo in my name on the official certificate from Codecademy.", "Category": "Certificate Issue"},
    {"Complaint Text": "The name displayed on my Codecademy certificate is not my legal name as it should be.", "Category": "Certificate Issue"},
    {"Complaint Text": "I need my Codecademy certificate reissued because my name is incorrect.", "Category": "Certificate Issue"},
    {"Complaint Text": "My Codecademy certificate is invalid because it shows the wrong name.", "Category": "Certificate Issue"},
    {"Complaint Text": "The system at Codecademy has put an incorrect name on my certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "How do I fix an incorrect name on my Codecademy certificate?", "Category": "Certificate Issue"},
    {"Complaint Text": "My certificate from Codecademy has my old name on it, not my updated one.", "Category": "Certificate Issue"},
    {"Complaint Text": "The name on my professional certificate from Codecademy is misspelled.", "Category": "Certificate Issue"},
    {"Complaint Text": "Codecademy's automated system used my username instead of my full name on the certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "My first and last names are swapped on my Codecademy certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "The certificate generated by Codecademy for me has a major error in my name.", "Category": "Certificate Issue"},
    {"Complaint Text": "I cannot use my Codecademy certificate for professional purposes because the name is wrong.", "Category": "Certificate Issue"},
    {"Complaint Text": "The name on my certificate does not match the name on my Codecademy account profile.", "Category": "Certificate Issue"},
    {"Complaint Text": "There has been a mistake, and my Codecademy certificate displays the wrong person's name.", "Category": "Certificate Issue"},
    {"Complaint Text": "I need Codecademy to correct the spelling of my name on my certificate.", "Category": "Certificate Issue"},
    {"Complaint Text": "The credential I received from Codecademy is useless to me because the name is incorrect.", "Category": "Certificate Issue"},
    {"Complaint Text": "My middle initial is missing, and my last name is wrong on the Codecademy certificate.", "Category": "Certificate Issue"},
]

# %%
complaints_data += [
    # Complaint 90 – Customer Support Issue
    {"Complaint Text": "I have sent multiple emails to Codecademy support with no response.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The customer support team at Codecademy is completely ignoring my support tickets.", "Category": "Customer Support Issue"},
    {"Complaint Text": "It has been over a week, and I still haven't received a reply from Codecademy support.", "Category": "Customer Support Issue"},
    {"Complaint Text": "My queries to the Codecademy support team have gone unanswered.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I am unable to get any help because Codecademy support is not responding.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The support team at Codecademy is completely unresponsive to customer inquiries.", "Category": "Customer Support Issue"},
    {"Complaint Text": "My urgent query about a payment issue has been met with silence from Codecademy support.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I am stuck and cannot proceed because the Codecademy support team will not answer me.", "Category": "Customer Support Issue"},
    {"Complaint Text": "It seems impossible to get a response from the Codecademy customer support team.", "Category": "Customer Support Issue"},
    {"Complaint Text": "All my attempts to contact Codecademy support have been ignored.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The lack of response from the Codecademy support team is extremely frustrating.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Codecademy's support is like a black hole; my queries go in, but nothing comes out.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I have a critical issue, but the Codecademy support team is not responding to my messages.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I am getting no acknowledgement or reply from Codecademy's support department.", "Category": "Customer Support Issue"},
    {"Complaint Text": "Is there any other way to contact Codecademy? Their main support team is not responding.", "Category": "Customer Support Issue"},
    {"Complaint Text": "My open support ticket with Codecademy has had no response for many days.", "Category": "Customer Support Issue"},
    {"Complaint Text": "The customer service at Codecademy is nonexistent; they don't respond to queries.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I'm very disappointed with the complete lack of communication from the Codecademy support team.", "Category": "Customer Support Issue"},
    {"Complaint Text": "My repeated messages to the Codecademy help center have not been answered.", "Category": "Customer Support Issue"},
    {"Complaint Text": "I feel abandoned by Codecademy as their support team has not responded to any of my queries.", "Category": "Customer Support Issue"},
]

# %%
complaints_data += [
    # Complaint Set – Course Access Issue (1/5)
    {"Complaint Text": "I paid for the Data Science course on Codecademy, but I'm still locked out.", "Category": "Course Access Issue"},
    {"Complaint Text": "My progress on the Python 3 course is not being saved on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "The next module in my Web Development path on Codecademy is not unlocking.", "Category": "Course Access Issue"},
    {"Complaint Text": "A course I was halfway through on Codecademy has completely disappeared from my dashboard.", "Category": "Course Access Issue"},
    {"Complaint Text": "The link to start my enrolled course on Codecademy is broken.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy platform says I haven't completed the prerequisites, but I have.", "Category": "Course Access Issue"},
    {"Complaint Text": "I'm getting a '403 Forbidden' error when trying to access my Codecademy course.", "Category": "Course Access Issue"},
    {"Complaint Text": "My new course is not appearing on my Codecademy 'My Courses' page.", "Category": "Course Access Issue"},
    {"Complaint Text": "The course content page on Codecademy is just a blank white screen.", "Category": "Course Access Issue"},
    {"Complaint Text": "After logging back in, Codecademy reset all my progress for the SQL course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy's system fails to recognize that I have completed a lesson, blocking me.", "Category": "Course Access Issue"},
    {"Complaint Text": "A course I had lifetime access to on Codecademy is now demanding payment again.", "Category": "Course Access Issue"},
    {"Complaint Text": "I am unable to access any of my enrolled courses on the Codecademy mobile app.", "Category": "Course Access Issue"},
    {"Complaint Text": "The platform is not tracking my completed exercises on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy removed a course I was studying without any notification or replacement.", "Category": "Course Access Issue"},
    {"Complaint Text": "Access to the final project of my Codecademy course is denied.", "Category": "Course Access Issue"},
    {"Complaint Text": "The course materials for my subscribed path on Codecademy are not loading.", "Category": "Course Access Issue"},
    {"Complaint Text": "My enrollment in the Codecademy course is confirmed, but access is still blocked.", "Category": "Course Access Issue"},
    {"Complaint Text": "The weekly lessons for my Codecademy course are not being released on schedule.", "Category": "Course Access Issue"},
    {"Complaint Text": "I can't get past the first chapter of my Codecademy course; the rest is locked.", "Category": "Course Access Issue"},
]

# %%
complaints_data += [
    # Complaint Set – Course Access Issue (1/6)
    {"Complaint Text": "I paid for the Pro subscription on Codecademy, but all the courses are still locked.", "Category": "Course Access Issue"},
    {"Complaint Text": "My progress in the 'Data Science' career path on Codecademy is not being saved.", "Category": "Course Access Issue"},
    {"Complaint Text": "The next module in my Web Development course on Codecademy is not unlocking even though I finished the previous one.", "Category": "Course Access Issue"},
    {"Complaint Text": "The Python course I was halfway through on Codecademy has disappeared from my dashboard.", "Category": "Course Access Issue"},
    {"Complaint Text": "The enrollment link for the course I just signed up for on Codecademy is broken.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy's platform claims I haven't completed a prerequisite, but my profile shows I have.", "Category": "Course Access Issue"},
    {"Complaint Text": "I'm consistently getting a '403 Forbidden' error when trying to access my Codecademy course materials.", "Category": "Course Access Issue"},
    {"Complaint Text": "My newly purchased course is not appearing on the 'My Courses' page on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "The entire course content page on Codecademy is just a blank screen.", "Category": "Course Access Issue"},
    {"Complaint Text": "After logging out and back in, Codecademy completely reset my progress for the SQL course.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy's system fails to acknowledge my lesson completion, preventing me from moving forward.", "Category": "Course Access Issue"},
    {"Complaint Text": "A course I had previously purchased with 'lifetime access' on Codecademy is now prompting me to pay again.", "Category": "Course Access Issue"},
    {"Complaint Text": "I am unable to access any of my enrolled courses on the Codecademy mobile app; it shows 'No Courses'.", "Category": "Course Access Issue"},
    {"Complaint Text": "The platform is not tracking my completed exercises in the sidebar on Codecademy.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy retired a course I was actively studying without any notification or alternative.", "Category": "Course Access Issue"},
    {"Complaint Text": "Access to the final project of my Front-End Engineer path on Codecademy is denied.", "Category": "Course Access Issue"},
    {"Complaint Text": "The downloadable course materials for my subscribed path on Codecademy are not loading.", "Category": "Course Access Issue"},
    {"Complaint Text": "My enrollment in the new Codecademy course is confirmed via email, but access is still blocked on the site.", "Category": "Course Access Issue"},
    {"Complaint Text": "The weekly lessons for my 'Learn Java' course on Codecademy are not being released on the scheduled day.", "Category": "Course Access Issue"},
    {"Complaint Text": "I can't get past the introductory chapter of my Codecademy course; all subsequent sections are locked.", "Category": "Course Access Issue"},

    # Complaint Set – Course Access Issue (2/6)
    {"Complaint Text": "Despite a successful payment confirmation, I am denied access to my premium Codecademy course.", "Category": "Course Access Issue"},
    {"Complaint Text": "My learning path on Codecademy is now broken because a required course has become inaccessible.", "Category": "Course Access Issue"},
    {"Complaint Text": "The checkmarks indicating completed lessons on Codecademy vanish every time I refresh the page.", "Category": "Course Access Issue"},
    {"Complaint Text": "I can't resume my course where I left off on Codecademy; it always sends me back to the very beginning.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy's platform won't allow me to start the course I just paid for.", "Category": "Course Access Issue"},
    {"Complaint Text": "The course I enrolled in on Codecademy is perpetually showing as 'unavailable'.", "Category": "Course Access Issue"},
    {"Complaint Text": "I am a paying Pro member but I cannot get into the Codecademy course I signed up for.", "Category": "Course Access Issue"},
    {"Complaint Text": "My course dashboard on Codecademy is not displaying my true progress; it's stuck at 10%.", "Category": "Course Access Issue"},
    {"Complaint Text": "The 'Next Lesson' button is permanently greyed out on Codecademy, even after completing the current lesson.", "Category": "Course Access Issue"},
    {"Complaint Text": "I lost access to all my courses immediately after my Codecademy subscription successfully renewed.", "Category": "Course Access Issue"},
    {"Complaint Text": "The link to my new Codecademy course that I received in the confirmation email leads to a 404 page.", "Category": "Course Access Issue"},
    {"Complaint Text": "My completed modules on Codecademy are being marked as 'not started' the next day.", "Category": "Course Access Issue"},
    {"Complaint Text": "I have the payment receipt from Codecademy but have no access to the course I purchased.", "Category": "Course Access Issue"},
    {"Complaint Text": "Codecademy's system has lost all track of which parts of the course I have already finished.", "Category": "Course Access Issue"},
    {"Complaint Text": "The platform is not acknowledging my lesson completions, which is halting my overall progress.", "Category": "Course Access Issue"},
    {"Complaint Text": "The course progress bar on Codecademy has been stuck at 0% for three days and is not updating.", "Category": "Course Access Issue"},
    {"Complaint Text": "I am forced to redo lessons on Codecademy because my progress is not being tracked or saved.", "Category": "Course Access Issue"},
    {"Complaint Text": "Access to a course I was actively studying on Codecademy was terminated abruptly without reason.", "Category": "Course Access Issue"},
    {"Complaint Text": "My Codecademy account clearly shows I'm enrolled, but all the course content remains locked.", "Category": "Course Access Issue"},
    {"Complaint Text": "I'm logged into my Pro account, but Codecademy claims I don't have a subscription to access my course.", "Category": "Course Access Issue"},
]

# %%
created_dataset=pd.DataFrame(complaints_data)

# %%
created_dataset.shape
# Out:
# (1580, 2)

# %%
created_dataset.head()
# Out:
#                                       Complaint Text       Category
# 0  Double payment processed for one membership on...  Payment Issue
# 1  Double payment processed for one enrollment on...  Payment Issue
# 2  Double payment processed for one course access...  Payment Issue
# 3  Double payment processed for one enrollment on...  Payment Issue
# 4  Double payment processed for one membership on...  Payment Issue

# %%
created_dataset["Category"].value_counts()
# Out:
# Category
# Customer Support Issue           210
# Payment Issue                    200
# Technical Glitch                 200
# Refund Issue                     200
# Course Access Issue              160
# Certificate Issue                160
# Instructor Issue                 150
# Misleading Course Description    150
# Content Quality Issue            150
# Name: count, dtype: int64

# %%
combined_df = pd.concat([created_dataset, unique_df])

# %%
combined_df.shape
# Out:
# (1670, 2)

# %%
combined_df["Category"].value_counts()
# Out:
# Category
# Customer Support Issue           220
# Payment Issue                    210
# Technical Glitch                 210
# Refund Issue                     210
# Course Access Issue              170
# Certificate Issue                170
# Instructor Issue                 160
# Misleading Course Description    160
# Content Quality Issue            160
# Name: count, dtype: int64

# %%
combined_df.to_csv("updated_dataset.csv")
